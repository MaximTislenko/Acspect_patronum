# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximTislenko/Acspect_patronum/blob/main/%D0%94%D0%BE%D0%B1%D1%80%D0%BE_%D0%BF%D0%BE%D0%B6%D0%B0%D0%BB%D0%BE%D0%B2%D0%B0%D1%82%D1%8C_%D0%B2_Colab_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #Формирование таблицы DataFrame

# %%
df = pd.DataFrame({'A':(0, 1, 2, 3, 4),
                   'B' : (0.5558, 0.4568, 0.7856, 0.5512, 0.8568),
                   'C' : (0.2364, 0.7896, 1.2356, 4.5618, 0.1234),
                   'D' : (0.1234, 0.5678, 0.9123, 0.4567, 0.8912)})

# %%
##Таблица

# %%
df
# Out:
#    A       B       C       D
# 0  0  0.5558  0.2364  0.1234
# 1  1  0.4568  0.7896  0.5678
# 2  2  0.7856  1.2356  0.9123
# 3  3  0.5512  4.5618  0.4567
# 4  4  0.8568  0.1234  0.8912

# %%
##Типы данных

# %%
df.dtypes
# Out:
# A      int64
# B    float64
# C    float64
# D    float64
# dtype: object

# %% [markdown]
# ##Срезы

# %%
# df['A']
df['C']
# Out:
# 0    0.2364
# 1    0.7896
# 2    1.2356
# 3    4.5618
# 4    0.1234
# Name: C, dtype: float64

# %% [markdown]
# ##Извлечение данных из таблицы

# %%
df
# Out:
#    A       B       C       D
# 0  0  0.5558  0.2364  0.1234
# 1  1  0.4568  0.7896  0.5678
# 2  2  0.7856  1.2356  0.9123
# 3  3  0.5512  4.5618  0.4567
# 4  4  0.8568  0.1234  0.8912

# %% [markdown]
# ##Вытаскивание данных

# %%
x=1
m = df.iat [x,1] * df.iat [x,2]
print(m)
# Out:
# 0.36068927999999995

# %% [markdown]
# ##Функция

# %%
def z_score (x):
  z = df.iat [x,1] * df.iat [x,2]
  print(z)

# %%
def z_score (x):
  z = df.iat [x,1] * df.iat [x,2]
  return z

# %%
df
# Out:
#    A       B       C       D
# 0  0  0.5558  0.2364  0.1234
# 1  1  0.4568  0.7896  0.5678
# 2  2  0.7856  1.2356  0.9123
# 3  3  0.5512  4.5618  0.4567
# 4  4  0.8568  0.1234  0.8912

# %%
A = z_score(1)
print (A)
# Out:
# 0.36068927999999995
