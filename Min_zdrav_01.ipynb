# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximTislenko/Acspect_patronum/blob/main/Min_zdrav_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests as req
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO

# %%
link = 'https://apicr.minzdrav.gov.ru/api.ashx?op=GetJsonClinrecs&ssid=undefined'
response = req.get(link).text
soup = BeautifulSoup(response, 'lxml')
# blok = soup.find('div', id = "data-v-66e287f7")
soup
# print(blok)
# Out:
# <html><body><p>[{"id":"66_3","status":0,"db_id":10,"code":66,"version":3,"ver":1,"age":2,"name":"Рак носоглотки","Mkb":["C11"],"ass":"Общероссийская общественная организация \"Российское общество детских онкологов\", Национальное общество детских гематологов, онкологов","publish_date":"\/Date(1589835600000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"68_1","status":0,"db_id":11,"code":68,"version":1,"ver":1,"age":2,"name":"Гепатобластома","Mkb":["C22.2"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\/Date(1589922000000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"69_1","status":0,"db_id":12,"code":69,"version":1,"ver":1,"age":2,"name":"Экстракраниальные герминогенно-клеточные опухоли","Mkb":["C38.1","C48.0","C49.5","C62","C49.0","C49.9","C62.0","C62.1","C62.9"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\/Date(1589835600000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"70_1","status":0,"db_id":13,"code":70,"version":1,"ver":1,"age":2,"name":"Злокачественные новообразования костей и суставных хрящей: остеосаркома, саркома Юинга","Mkb":["C40","C41"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\/Date(1589922000000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"78_1","status":0,"db_id":15,"code":78,"version":1,"ver":1,"age":2,"name":"Нейробластома","Mkb":["C47.3","C47.4","C47.5","C47.6","C47.8","C47.9","C48.0","C74.1","C74.9","C76.0","C76.1","C76.2","C76.7","C76.8"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\/Date(1589922000000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"67_1","status":0,"db_id":25,"code":67,"version":1,"ver":1,"age":2,"name":"Злокачественные новообразования почек, почечных лоханок, мочеточника, других и неуточненных мочевых органов","Mkb":["C64","C65","C68","C66"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\/Date(1589922000000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"71_1","status":0,"db_id":27,"code":71,"version":1,"ver":1,"age":2,"name":"Интраокулярная ретинобластома","Mkb":["C69.2"],"ass":"Общероссийская общественная организация \"Ассоциация врачей-офтальмологов\", Национальное общество детских гематологов, онкологов, Общероссийская общественная организация \"Российское общество детских онкологов\", Общероссийская общественная организация «Общество офтальмологов России»","publish_date":"\/Date(1625576071627)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"76_1","status":0,"db_id":29,"code":76,"version":1,"ver":1,"age":2,"name":"Саркомы мягких тканей","Mkb":["C22.4","C48.0","C49.0","C49.1","C49.2","C49.3","C49.4","C49.5","C49.6","C49.8","C49.9","C76.3","C49.7"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\/Date(1589922000000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"100_1","status":0,"db_id":30,"code":100,"version":1,"ver":1,"age":1,"name":"Увеальная меланома","Mkb":["C69.8","C69.3","C69.4"],"ass":"Ассоциация онкологов России, Общероссийская общественная организация \"Ассоциация врачей-офтальмологов\", Ассоциация специалистов по проблемам меланомы, Общероссийская общественная организация «Общество офтальмологов России»","publish_date":"\/Date(1587675600000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"109_1","status":0,"db_id":32,"code":109,"version":1,"ver":1,"age":2,"name":"Миопия","Mkb":["H52.1"],"ass":"Общероссийская общественная организация \"Ассоциация врачей-офтальмологов\"","publish_date":"\/Date(1611694800000)\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"96_1","status":0,"db_id":50,"code":96,"version":1,"ver":1,"age":1,"name":"Глаукома первичная открытоугольная","Mkb":["H4 ...

# %%
link = 'https://apicr.minzdrav.gov.ru/api.ashx?op=GetJsonClinrecs&ssid=undefined'
response = req.get(link).text
response
# Out:
# '[{"id":"66_3","status":0,"db_id":10,"code":66,"version":3,"ver":1,"age":2,"name":"Рак носоглотки","Mkb":["C11"],"ass":"Общероссийская общественная организация \\"Российское общество детских онкологов\\", Национальное общество детских гематологов, онкологов","publish_date":"\\/Date(1589835600000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"68_1","status":0,"db_id":11,"code":68,"version":1,"ver":1,"age":2,"name":"Гепатобластома","Mkb":["C22.2"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\\/Date(1589922000000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"69_1","status":0,"db_id":12,"code":69,"version":1,"ver":1,"age":2,"name":"Экстракраниальные герминогенно-клеточные опухоли","Mkb":["C38.1","C48.0","C49.5","C62","C49.0","C49.9","C62.0","C62.1","C62.9"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\\/Date(1589835600000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"70_1","status":0,"db_id":13,"code":70,"version":1,"ver":1,"age":2,"name":"Злокачественные новообразования костей и суставных хрящей: остеосаркома, саркома Юинга","Mkb":["C40","C41"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\\/Date(1589922000000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"78_1","status":0,"db_id":15,"code":78,"version":1,"ver":1,"age":2,"name":"Нейробластома","Mkb":["C47.3","C47.4","C47.5","C47.6","C47.8","C47.9","C48.0","C74.1","C74.9","C76.0","C76.1","C76.2","C76.7","C76.8"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\\/Date(1589922000000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"67_1","status":0,"db_id":25,"code":67,"version":1,"ver":1,"age":2,"name":"Злокачественные новообразования почек, почечных лоханок, мочеточника, других и неуточненных мочевых органов","Mkb":["C64","C65","C68","C66"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\\/Date(1589922000000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"71_1","status":0,"db_id":27,"code":71,"version":1,"ver":1,"age":2,"name":"Интраокулярная ретинобластома","Mkb":["C69.2"],"ass":"Общероссийская общественная организация \\"Ассоциация врачей-офтальмологов\\", Национальное общество детских гематологов, онкологов, Общероссийская общественная организация \\"Российское общество детских онкологов\\", Общероссийская общественная организация «Общество офтальмологов России»","publish_date":"\\/Date(1625576071627)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"76_1","status":0,"db_id":29,"code":76,"version":1,"ver":1,"age":2,"name":"Саркомы мягких тканей","Mkb":["C22.4","C48.0","C49.0","C49.1","C49.2","C49.3","C49.4","C49.5","C49.6","C49.8","C49.9","C76.3","C49.7"],"ass":"Национальное общество детских гематологов, онкологов","publish_date":"\\/Date(1589922000000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"100_1","status":0,"db_id":30,"code":100,"version":1,"ver":1,"age":1,"name":"Увеальная меланома","Mkb":["C69.8","C69.3","C69.4"],"ass":"Ассоциация онкологов России, Общероссийская общественная организация \\"Ассоциация врачей-офтальмологов\\", Ассоциация специалистов по проблемам меланомы, Общероссийская общественная организация «Общество офтальмологов России»","publish_date":"\\/Date(1587675600000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"109_1","status":0,"db_id":32,"code":109,"version":1,"ver":1,"age":2,"name":"Миопия","Mkb":["H52.1"],"ass":"Общероссийская общественная организация \\"Ассоциация врачей-офтальмологов\\"","publish_date":"\\/Date(1611694800000)\\/","NPC_approved":true,"apply_status":"Применяется","prev_cr_id":null},{"id":"96_1","status":0,"db_id":50,"code":96,"version":1,"ver":1,"age":1,"name":"Глаукома первичная открытоугол ...

# %%
type(response)
# Out:
# str

# %%
link = 'https://apicr.minzdrav.gov.ru/api.ashx?op=GetJsonClinrecs&ssid=undefined'
response = req.get(link).json()
response
# Out:
# [{'id': '66_3',
#   'status': 0,
#   'db_id': 10,
#   'code': 66,
#   'version': 3,
#   'ver': 1,
#   'age': 2,
#   'name': 'Рак носоглотки',
#   'Mkb': ['C11'],
#   'ass': 'Общероссийская общественная организация "Российское общество детских онкологов", Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589835600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '68_1',
#   'status': 0,
#   'db_id': 11,
#   'code': 68,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Гепатобластома',
#   'Mkb': ['C22.2'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589922000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '69_1',
#   'status': 0,
#   'db_id': 12,
#   'code': 69,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Экстракраниальные герминогенно-клеточные опухоли',
#   'Mkb': ['C38.1',
#    'C48.0',
#    'C49.5',
#    'C62',
#    'C49.0',
#    'C49.9',
#    'C62.0',
#    'C62.1',
#    'C62.9'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589835600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '70_1',
#   'status': 0,
#   'db_id': 13,
#   'code': 70,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Злокачественные новообразования костей и суставных хрящей: остеосаркома, саркома Юинга',
#   'Mkb': ['C40', 'C41'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589922000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '78_1',
#   'status': 0,
#   'db_id': 15,
#   'code': 78,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Нейробластома',
#   'Mkb': ['C47.3',
#    'C47.4',
#    'C47.5',
#    'C47.6',
#    'C47.8',
#    'C47.9',
#    'C48.0',
#    'C74.1',
#    'C74.9',
#    'C76.0',
#    'C76.1',
#    'C76.2',
#    'C76.7',
#    'C76.8'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589922000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '67_1',
#   'status': 0,
#   'db_id': 25,
#   'code': 67,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Злокачественные новообразования почек, почечных лоханок, мочеточника, других и неуточненных мочевых органов',
#   'Mkb': ['C64', 'C65', 'C68', 'C66'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589922000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '71_1',
#   'status': 0,
#   'db_id': 27,
#   'code': 71,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Интраокулярная ретинобластома',
#   'Mkb': ['C69.2'],
#   'ass': 'Общероссийская общественная организация "Ассоциация врачей-офтальмологов", Национальное общество детских гематологов, онкологов, Общероссийская общественная организация "Российское общество детских онкологов", Общероссийская общественная организация «Общество офтальмологов России»',
#   'publish_date': '/Date(1625576071627)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '76_1',
#   'status': 0,
#   'db_id': 29,
#   'code': 76,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Саркомы мягких тканей',
#   'Mkb': ['C22.4',
#    'C48.0',
#    'C49.0',
#    'C49.1',
#    'C49.2',
#    'C49.3',
#    'C49.4',
#    'C49.5',
#    'C49.6',
#    'C49.8',
#    'C49.9',
#    'C76.3',
#    'C49.7'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589922000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '100_1',
#   'status': 0,
#   'db_id': 30,
#   'code': 100,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Увеальная меланома',
#   'Mkb': ['C69.8', 'C69.3', 'C69.4'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Ассоциация врачей-офтальмологов", Ассоциация специалистов по проблемам меланомы, Общероссийская общественная организация «Общество офтальмологов России»',
#   'publish_date': '/Date(1587675600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '109_1',
#   'status': 0,
#   'db_id': 32,
#   'code': 109,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Миопия',
#   'Mkb': ['H52.1'],
#   'ass': 'Общероссийская общественная организация "Ассоциация врачей-офтальмологов"',
#   'publish_date': '/Date(1611694800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '96_1',
#   'status': 0,
#   'db_id': 50,
#   'code': 96,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Глаукома первичная открытоугольная',
#   'Mkb': ['H40.1'],
#   'ass': 'Общероссийская общественная организация "Ассоциация врачей-офтальмологов", Общероссийская общественная организация «Общество офтальмологов России», Межрегиональная общественная организация «Глаукомное общество»',
#   'publish_date': '/Date(1611694800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '8_1',
#   'status': 0,
#   'db_id': 53,
#   'code': 8,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Недержание мочи',
#   'Mkb': ['N39.3', 'R32'],
#   'ass': 'Общероссийская общественная организация "Российское общество урологов", Общероссийская общественная организация «Российская ассоциация геронтологов и гериатров»',
#   'publish_date': '/Date(1604523600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '106_1',
#   'status': 0,
#   'db_id': 84,
#   'code': 106,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Ожоги глаз',
#   'Mkb': ['T26'],
#   'ass': 'Общероссийская общественная организация "Ассоциация врачей-офтальмологов"',
#   'publish_date': '/Date(1621601788717)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '116_1',
#   'status': 0,
#   'db_id': 93,
#   'code': 116,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Злокачественные опухоли слюнных желез',
#   'Mkb': ['C07', 'C08'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи", Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи"',
#   'publish_date': '/Date(1583096400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '130_1',
#   'status': 0,
#   'db_id': 107,
#   'code': 130,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Волосатоклеточный лейкоз',
#   'Mkb': ['C91.4'],
#   'ass': 'Ассоциация онкологов России, Национальное гематологическое общество, Российское профессиональное общество онкогематологов',
#   'publish_date': '/Date(1582578000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '131_1',
#   'status': 0,
#   'db_id': 108,
#   'code': 131,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Острые миелоидные лейкозы',
#   'Mkb': ['C92.6',
#    'C92.8',
#    'C92.0',
#    'C92.3',
#    'C92.5',
#    'C92.7',
#    'C92.9',
#    'C93.0',
#    'C94.0',
#    'C94.2'],
#   'ass': 'Ассоциация онкологов России, Некоммерческое партнерство содействия развитию гематологии и трансплантологии костного мозга "Национальное гематологическое общество"\r\n',
#   'publish_date': '/Date(1582232400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '132_1',
#   'status': 0,
#   'db_id': 109,
#   'code': 132,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Острый промиелоцитарный лейкоз',
#   'Mkb': ['C92.4'],
#   'ass': 'Ассоциация онкологов России, Национальное гематологическое общество',
#   'publish_date': '/Date(1582232400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '134_1',
#   'status': 0,
#   'db_id': 111,
#   'code': 134,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Хронический лимфоцитарный лейкоз /  лимфома из малых лимфоцитов',
#   'Mkb': ['C91.1'],
#   'ass': 'Ассоциация онкологов России, Национальное гематологическое общество, Российское профессиональное общество онкогематологов',
#   'publish_date': '/Date(1583096400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '136_1',
#   'status': 0,
#   'db_id': 113,
#   'code': 136,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Лимфома из клеток мантии',
#   'Mkb': ['C83.1'],
#   'ass': 'Ассоциация онкологов России, Некоммерческое партнерство содействия развитию гематологии и трансплантологии костного мозга "Национальное гематологическое общество"\r\n, Российское профессиональное общество онкогематологов',
#   'publish_date': '/Date(1587675600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '138_1',
#   'status': 0,
#   'db_id': 115,
#   'code': 138,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Нодальные Т-клеточные лимфомы',
#   'Mkb': ['C84.5', 'C84.6', 'C84.7', 'C84.9', 'C86.0', 'C86.5'],
#   'ass': 'Национальное общество детских гематологов, онкологов, Ассоциация онкологов России, Российское профессиональное общество онкогематологов, Некоммерческое партнерство содействия развитию гематологии и трансплантологии костного мозга "Национальное гематологическое общество"\r\n',
#   'publish_date': '/Date(1587934800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '139_1',
#   'status': 0,
#   'db_id': 116,
#   'code': 139,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Лимфома Ходжкина',
#   'Mkb': ['C81'],
#   'ass': 'Национальное общество детских гематологов, онкологов, Ассоциация онкологов России, Российское профессиональное общество онкогематологов, Некоммерческое партнерство содействия развитию гематологии и трансплантологии костного мозга "Национальное гематологическое общество"\r\n',
#   'publish_date': '/Date(1587934800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '140_1',
#   'status': 0,
#   'db_id': 117,
#   'code': 140,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Макроглобулинемия Вальденстрема',
#   'Mkb': ['C88.0'],
#   'ass': 'Национальное общество детских гематологов, онкологов, Ассоциация онкологов России, Российское профессиональное общество онкогематологов, Некоммерческое партнерство содействия развитию гематологии и трансплантологии костного мозга "Национальное гематологическое общество"\r\n',
#   'publish_date': '/Date(1587934800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '141_1',
#   'status': 0,
#   'db_id': 119,
#   'code': 141,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Миелодиспластический синдром',
#   'Mkb': ['D46'],
#   'ass': 'Ассоциация онкологов России, Национальное гематологическое общество',
#   'publish_date': '/Date(1582232400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '142_1',
#   'status': 0,
#   'db_id': 120,
#   'code': 142,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Хронический миелолейкоз',
#   'Mkb': ['C92.1'],
#   'ass': 'Ассоциация онкологов России, Национальное гематологическое общество',
#   'publish_date': '/Date(1582232400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '144_1',
#   'status': 0,
#   'db_id': 122,
#   'code': 144,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Множественная миелома',
#   'Mkb': ['C90.0'],
#   'ass': 'Ассоциация онкологов России, Национальное гематологическое общество, Российское профессиональное общество онкогематологов',
#   'publish_date': '/Date(1582232400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '151_1',
#   'status': 0,
#   'db_id': 129,
#   'code': 151,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Фолликулярная лимфома',
#   'Mkb': ['C82'],
#   'ass': 'Ассоциация онкологов России, Российское профессиональное общество онкогематологов, Некоммерческое партнерство содействия развитию гематологии и трансплантологии костного мозга "Национальное гематологическое общество"\r\n, Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1587934800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '153_1',
#   'status': 0,
#   'db_id': 131,
#   'code': 153,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Миокардиты ',
#   'Mkb': ['I51.4', 'I40', 'I41'],
#   'ass': 'Общероссийская общественная организация «Российское кардиологическое общество», Общероссийская общественная организация "Общество специалистов по сердечной недостаточности", Общероссийская общественная организация "Российское научное медицинское общество терапевтов", Общероссийская общественная организация "Российское общество патологоанатомов", Общероссийская общественная организация содействия развитию лучевой диагностики и терапии "Российское общество рентгенологов и радиологов"  , Евразийского общества терапевтов\r\n',
#   'publish_date': '/Date(1605128400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '155_1',
#   'status': 0,
#   'db_id': 133,
#   'code': 155,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Стабильная ишемическая болезнь сердца',
#   'Mkb': ['I20.1',
#    'I20.8',
#    'I20.9',
#    'I25.0',
#    'I25.1',
#    'I25.2',
#    'I25.5',
#    'I25.6',
#    'I25.8',
#    'I25.9',
#    'I20.0',
#    'I25.3',
#    'I25.4'],
#   'ass': 'Общероссийская общественная организация «Российское кардиологическое общество», Автономная некоммерческая организация "Национальное общество по изучению атеросклероза", Некоммерческое партнерство "Национальное общество по атеротромбозу", Ассоциация сердечно-сосудистых хирургов России',
#   'publish_date': '/Date(1596747600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '156_1',
#   'status': 0,
#   'db_id': 134,
#   'code': 156,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Хроническая сердечная недостаточность ',
#   'Mkb': ['I50.1', 'I50.9', 'I50.0'],
#   'ass': 'Общероссийская общественная организация «Российское кардиологическое общество», Автономная некоммерческая организация "Национальное общество по изучению сердечной недостаточности и заболеваний миокарда", Общероссийская общественная организация "Общество специалистов по сердечной недостаточности"',
#   'publish_date': '/Date(1596747600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '159_1',
#   'status': 0,
#   'db_id': 137,
#   'code': 159,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Легочная гипертензия, в том числе хроническая тромбоэмболическая легочная гипертензия',
#   'Mkb': ['I27.8', 'I27.0', 'I27.2'],
#   'ass': 'Общероссийская общественная организация «Российское кардиологическое общество», Ассоциация сердечно-сосудистых хирургов России, Общероссийская общественная организация "Федерация анестезиологов и реаниматологов", Ассоциация ревматологов России, Российское респираторное общество, Национальный конгресс лучевых диагностов\r\n',
#   'publish_date': '/Date(1605560400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '160_1',
#   'status': 0,
#   'db_id': 138,
#   'code': 160,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Брадиаритмии и нарушения проводимости',
#   'Mkb': ['I44',
#    'I45',
#    'I46',
#    'I44.0',
#    'I44.1',
#    'I44.2',
#    'I44.3',
#    'I44.4',
#    'I44.5',
#    'I44.6',
#    'I44.7',
#    'I45.0',
#    'I45.1',
#    'I45.2',
#    'I45.3',
#    'I45.4',
#    'I45.5',
#    'I45.8',
#    'I45.9',
#    'I46.0',
#    'I46.1',
#    'I46.9',
#    'I49.5'],
#   'ass': 'Общероссийская общественная организация «Российское кардиологическое общество», Всероссийское научное общество специалистов по клинической электрофизиологии, аритмологии и электростимуляции, Ассоциация сердечно-сосудистых хирургов России',
#   'publish_date': '/Date(1597006800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '173_1',
#   'status': 0,
#   'db_id': 148,
#   'code': 173,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Полип анального канала',
#   'Mkb': ['K62.0'],
#   'ass': 'Общероссийская общественная организация "Ассоциация колопроктологов России"',
#   'publish_date': '/Date(1590526800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '178_1',
#   'status': 0,
#   'db_id': 153,
#   'code': 178,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Геморрой',
#   'Mkb': ['K64'],
#   'ass': 'Общероссийская общественная организация "Ассоциация колопроктологов России"',
#   'publish_date': '/Date(1590526800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '191_1',
#   'status': 0,
#   'db_id': 166,
#   'code': 191,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Свищ заднего прохода',
#   'Mkb': ['K60.3'],
#   'ass': 'Общероссийская общественная организация "Ассоциация колопроктологов России"',
#   'publish_date': '/Date(1590526800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '257_1',
#   'status': 0,
#   'db_id': 180,
#   'code': 257,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Миома матки',
#   'Mkb': ['D25', 'D26', 'O34.1'],
#   'ass': 'Российское общество акушеров-гинекологов',
#   'publish_date': '/Date(1604264400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '259_1',
#   'status': 0,
#   'db_id': 182,
#   'code': 259,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Эндометриоз',
#   'Mkb': ['N80'],
#   'ass': 'Российское общество акушеров-гинекологов',
#   'publish_date': '/Date(1604264400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '263_1',
#   'status': 0,
#   'db_id': 186,
#   'code': 263,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Анафилактический шок',
#   'Mkb': ['T78.0', 'T78.2', 'T80.5', 'T88.6'],
#   'ass': 'Российская ассоциация аллергологов и клинических иммунологов, Общероссийская общественная организация "Федерация анестезиологов и реаниматологов"',
#   'publish_date': '/Date(1612213200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '267_1',
#   'status': 0,
#   'db_id': 189,
#   'code': 267,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Наследственный ангиоотёк',
#   'Mkb': ['D84.1'],
#   'ass': 'Союз педиатров России, Российская ассоциация аллергологов и клинических иммунологов, Национальная Ассоциация Экспертов в области Первичных Иммунодефицитов, Ассоциация медицинских генетиков',
#   'publish_date': '/Date(1612299600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '283_1',
#   'status': 0,
#   'db_id': 196,
#   'code': 283,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Гипертрофическая кардиомиопатия',
#   'Mkb': ['I42.1', 'I42.2'],
#   'ass': 'Общероссийская общественная организация «Российское кардиологическое общество», Ассоциация сердечно-сосудистых хирургов России',
#   'publish_date': '/Date(1597006800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '284_1',
#   'status': 0,
#   'db_id': 197,
#   'code': 284,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Катаракта старческая',
#   'Mkb': ['H25.0', 'H25.1', 'H25.2', 'H25.8', 'H25.9'],
#   'ass': 'Общероссийская общественная организация «Общество офтальмологов России», Общероссийская общественная организация «Межрегиональная ассоциация врачей-офтальмологов»',
#   'publish_date': '/Date(1583355600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '331_1',
#   'status': 0,
#   'db_id': 213,
#   'code': 331,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Преждевременные роды ',
#   'Mkb': ['O60', 'O60.0', 'O60.1', 'O60.2', 'O60.3', 'O47.0', 'O42'],
#   'ass': 'Российское общество акушеров-гинекологов, Ассоциация акушерских анестезиологов-реаниматологов\r\n',
#   'publish_date': '/Date(1604955600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '495_1',
#   'status': 0,
#   'db_id': 344,
#   'code': 495,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Рак желчевыводящей системы',
#   'Mkb': ['C22.1', 'C23', 'C24.0'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1586379600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '497_1',
#   'status': 0,
#   'db_id': 346,
#   'code': 497,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Мезотелиома плевры, брюшины  и других локализаций',
#   'Mkb': ['C45.1', 'C45.2', 'C45.7', 'C45.9', 'C45.0'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1586379600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '501_1',
#   'status': 0,
#   'db_id': 351,
#   'code': 501,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак вульвы',
#   'Mkb': ['C51'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация «Российское общество специалистов по профилактике и лечению опухолей репродуктивной системы»',
#   'publish_date': '/Date(1582750800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '502_1',
#   'status': 0,
#   'db_id': 352,
#   'code': 502,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Опухоли средостения',
#   'Mkb': ['C38.1', 'C38.2', 'C38.3', 'C37.9'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1586466000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '51_1',
#   'status': 0,
#   'db_id': 367,
#   'code': 51,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак полового члена',
#   'Mkb': ['C60'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество онкоурологов", Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация "Российское общество урологов", Общероссийская общественная организация "Российское общество онкопатологов"',
#   'publish_date': '/Date(1582837200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '74_1',
#   'status': 0,
#   'db_id': 689,
#   'code': 74,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Рак щитовидной железы',
#   'Mkb': ['C73'],
#   'ass': 'Общероссийская общественная организация "Российское общество детских онкологов", Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1605042000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '7_1',
#   'status': 0,
#   'db_id': 690,
#   'code': 7,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Мочекаменная болезнь',
#   'Mkb': ['N20'],
#   'ass': 'Общероссийская общественная организация "Российское общество урологов"',
#   'publish_date': '/Date(1590958800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '574_1',
#   'status': 0,
#   'db_id': 719,
#   'code': 574,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак желудка',
#   'Mkb': ['C16'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1586379600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '297_1',
#   'status': 0,
#   'db_id': 730,
#   'code': 297,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Карцинома Меркеля',
#   'Mkb': ['C44'],
#   'ass': 'Ассоциация онкологов России, Ассоциация специалистов по проблемам меланомы, Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1581886800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '475_1',
#   'status': 0,
#   'db_id': 747,
#   'code': 475,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак гортани ',
#   'Mkb': ['C32'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи"',
#   'publish_date': '/Date(1586379600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '529_1',
#   'status': 0,
#   'db_id': 750,
#   'code': 529,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Острый лимфобластный лейкоз',
#   'Mkb': ['C91.0'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589835600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '535_1',
#   'status': 0,
#   'db_id': 755,
#   'code': 535,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак носоглотки',
#   'Mkb': ['C11'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи"',
#   'publish_date': '/Date(1585688400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '537_1',
#   'status': 0,
#   'db_id': 757,
#   'code': 537,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак шейки матки',
#   'Mkb': ['C53'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация «Российское общество специалистов по профилактике и лечению опухолей репродуктивной системы»',
#   'publish_date': '/Date(1583096400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '541_1',
#   'status': 0,
#   'db_id': 761,
#   'code': 541,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Неэпителиальные опухоли яичников',
#   'Mkb': ['C56'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация «Российское общество специалистов по профилактике и лечению опухолей репродуктивной системы»',
#   'publish_date': '/Date(1584651600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '547_2',
#   'status': 0,
#   'db_id': 767,
#   'code': 547,
#   'version': 2,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак яичников / рак маточной трубы / первичный рак брюшины',
#   'Mkb': ['C48.0', 'C48.1', 'C48.2', 'C56', 'C57'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация «Российское общество специалистов по профилактике и лечению опухолей репродуктивной системы»',
#   'publish_date': '/Date(1583096400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '341_1',
#   'status': 0,
#   'db_id': 780,
#   'code': 341,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Рак коры надпочечника (Адренокортикальный рак)',
#   'Mkb': ['C74'],
#   'ass': 'Ассоциация онкологов России, Российская ассоциация эндокринологов',
#   'publish_date': '/Date(1586466000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '344_1',
#   'status': 0,
#   'db_id': 784,
#   'code': 344,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Злокачественные новообразования  влагалища',
#   'Mkb': ['C52'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация «Российское общество специалистов по профилактике и лечению опухолей репродуктивной системы»',
#   'publish_date': '/Date(1582664400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '277_1',
#   'status': 0,
#   'db_id': 794,
#   'code': 277,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Язвенная болезнь',
#   'Mkb': ['K25', 'K26'],
#   'ass': 'Российская Гастроэнтерологическая Ассоциация, Ассоциация "Эндоскопическое общество "РЭндО", Российское общество колоректальных хирургов',
#   'publish_date': '/Date(1590699600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '330_1',
#   'status': 0,
#   'db_id': 796,
#   'code': 330,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак трахеи',
#   'Mkb': ['C33'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1583096400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '569_1',
#   'status': 0,
#   'db_id': 812,
#   'code': 569,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Желудочковые нарушения ритма. Желудочковые тахикардии и внезапная сердечная смерть',
#   'Mkb': ['I47.0',
#    'I47.2',
#    'I49',
#    'I46',
#    'I46.0',
#    'I46.1',
#    'I46.9',
#    'I47.0',
#    'I47.9',
#    'I49.0',
#    'I49.3',
#    'I49.4',
#    'I49.8',
#    'I49.9'],
#   'ass': 'Общероссийская общественная организация «Российское кардиологическое общество», Всероссийское научное общество специалистов по клинической электрофизиологии, аритмологии и электростимуляции, Всероссийская общественная организация "Ассоциация детских кардиологов России", Общества холтеровского мониторирования и неинвазивной электрокардиологии\r\n',
#   'publish_date': '/Date(1605128400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '551_1',
#   'status': 0,
#   'db_id': 822,
#   'code': 551,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Гастроинтестинальные стромальные опухоли',
#   'Mkb': ['C15', 'C20', 'C48'],
#   'ass': 'Ассоциация онкологов России',
#   'publish_date': '/Date(1582578000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '75_1',
#   'status': 0,
#   'db_id': 828,
#   'code': 75,
#   'version': 1,
#   'ver': 1,
#   'age': 2,
#   'name': 'Опухоли слюнных желез у детей',
#   'Mkb': ['C07', 'C08', 'C06.9', 'D11', 'D10.3'],
#   'ass': 'Национальное общество детских гематологов, онкологов, Общероссийская общественная организация "Российское общество детских онкологов"',
#   'publish_date': '/Date(1589835600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '578_1',
#   'status': 0,
#   'db_id': 831,
#   'code': 578,
#   'version': 1,
#   'ver': 1,
#   'age': 3,
#   'name': 'Первичные опухоли центральной нервной системы ',
#   'Mkb': ['C70', 'C71', 'C72'],
#   'ass': 'Ассоциация онкологов России, Ассоциация нейрохирургов России, Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1583787600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '80_1',
#   'status': 0,
#   'db_id': 833,
#   'code': 80,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Трофобластические опухоли',
#   'Mkb': ['C58'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация «Российское общество специалистов по профилактике и лечению опухолей репродуктивной системы»',
#   'publish_date': '/Date(1583096400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '553_1',
#   'status': 0,
#   'db_id': 847,
#   'code': 553,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Злокачественные новообразования  губы',
#   'Mkb': ['C00'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи"',
#   'publish_date': '/Date(1582664400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '584_1',
#   'status': 0,
#   'db_id': 850,
#   'code': 584,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Герминогенные опухоли у мужчин',
#   'Mkb': ['C62', 'C38.1', 'C38.2', 'C38.3', 'C38.8', 'C48.0', 'C48.8'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация "Российское общество онкоурологов", Общероссийская общественная организация "Российское общество онкопатологов", Общероссийская общественная организация "Российское общество урологов"',
#   'publish_date': '/Date(1582578000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '382_1',
#   'status': 0,
#   'db_id': 888,
#   'code': 382,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Фибрилляция и трепетание предсердий у взрослых ',
#   'Mkb': ['I48.0', 'I48.1', 'I48.2', 'I48.3', 'I48.4', 'I48.9'],
#   'ass': 'Общероссийская общественная организация «Российское кардиологическое общество», Всероссийское научное общество специалистов по клинической электрофизиологии, аритмологии и электростимуляции, Ассоциация сердечно-сосудистых хирургов России',
#   'publish_date': '/Date(1605128400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '3_1',
#   'status': 0,
#   'db_id': 895,
#   'code': 3,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак полости носа и придаточных пазух',
#   'Mkb': ['C30', 'C31'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи"',
#   'publish_date': '/Date(1586379600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '27_1',
#   'status': 0,
#   'db_id': 896,
#   'code': 27,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак гортаноглотки',
#   'Mkb': ['C12', 'C13'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи", Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1585688400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '4_1',
#   'status': 0,
#   'db_id': 897,
#   'code': 4,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Рак ротоглотки',
#   'Mkb': ['C09', 'C10', 'C01', 'C02.4', 'C05.1', 'C05.2'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи"',
#   'publish_date': '/Date(1583096400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '610_1',
#   'status': 0,
#   'db_id': 937,
#   'code': 610,
#   'version': 1,
#   'ver': 1,
#   'age': 1,
#   'name': 'Нейроэндокринные опухоли',
#   'Mkb': ['C15',
#    'C16',
#    'C17',
#    'C18',
#    'C21',
#    'C23',
#    'C24',
#    'C25',
#    'C26',
#    'C34',
#    'C19',
#    'C20',
#    'C37',
#    'C73'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Российская ассоциация эндокринологов',
#   'publish_date': '/Date(1586379600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '164_1',
#   'status': 0,
#   'db_id': 965,
#   'code': 164,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Злокачественные новообразования полости рта',
#   'Mkb': ['C02.0',
#    'C02.1',
#    'C02.2',
#    'C02.3',
#    'C02.8',
#    'C02.9',
#    'C03',
#    'C04',
#    'C05.0',
#    'C06'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи"',
#   'publish_date': '/Date(1582664400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '266_1',
#   'status': 0,
#   'db_id': 967,
#   'code': 266,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Солитарная (экстрамедуллярная) плазмоцитома',
#   'Mkb': ['C90.2'],
#   'ass': 'Ассоциация онкологов России, Российское профессиональное общество онкогематологов, Национальное гематологическое общество',
#   'publish_date': '/Date(1583096400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '289_1',
#   'status': 0,
#   'db_id': 969,
#   'code': 289,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Внутрипеченочный холестаз при беременности',
#   'Mkb': ['O26.6'],
#   'ass': 'Российское общество акушеров-гинекологов',
#   'publish_date': '/Date(1592168400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '291_1',
#   'status': 0,
#   'db_id': 971,
#   'code': 291,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Мукополисахаридоз тип I',
#   'Mkb': ['E76.0'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России',
#   'publish_date': '/Date(1582059600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '292_1',
#   'status': 0,
#   'db_id': 972,
#   'code': 292,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Мукополисахаридоз тип II',
#   'Mkb': ['E76.1'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России',
#   'publish_date': '/Date(1581973200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '293_1',
#   'status': 0,
#   'db_id': 973,
#   'code': 293,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Мукополисахаридоз тип VI',
#   'Mkb': ['E76.2'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России',
#   'publish_date': '/Date(1581973200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '294_1',
#   'status': 0,
#   'db_id': 974,
#   'code': 294,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Болезнь Ниманна-Пика тип С',
#   'Mkb': ['E75.2'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России',
#   'publish_date': '/Date(1581973200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '317_1',
#   'status': 0,
#   'db_id': 975,
#   'code': 317,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Болезнь Помпе',
#   'Mkb': ['E74.0'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России, РОО «Общество специалистов по нервно-мышечным заболеваниям»\r\n',
#   'publish_date': '/Date(1581973200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '329_1',
#   'status': 0,
#   'db_id': 977,
#   'code': 329,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Дифференцированный рак щитовидной железы',
#   'Mkb': ['C73'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи", Ассоциации эндокринных хирургов, Российская ассоциация эндокринологов',
#   'publish_date': '/Date(1582664400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '332_1',
#   'status': 0,
#   'db_id': 978,
#   'code': 332,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Медуллярный рак щитовидной железы',
#   'Mkb': ['C73'],
#   'ass': 'Ассоциация онкологов России, Ассоциации эндокринных хирургов, Общероссийская общественная организация "Российское общество специалистов по опухолям головы и шеи", Российская ассоциация эндокринологов',
#   'publish_date': '/Date(1582664400000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '346_1',
#   'status': 0,
#   'db_id': 979,
#   'code': 346,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Пограничные опухоли яичников',
#   'Mkb': ['C56'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация «Российское общество клинической онкологии», Общероссийская общественная организация «Российское общество специалистов по профилактике и лечению опухолей репродуктивной системы»',
#   'publish_date': '/Date(1582837200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '467_1',
#   'status': 0,
#   'db_id': 981,
#   'code': 467,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Базальноклеточный рак кожи',
#   'Mkb': ['C44'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Ассоциация врачей-офтальмологов", Общероссийская общественная организация «Российское общество клинической онкологии», Ассоциация специалистов по проблемам меланомы',
#   'publish_date': '/Date(1584651600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '476_2',
#   'status': 0,
#   'db_id': 984,
#   'code': 476,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'Плоскоклеточный рак кожи',
#   'Mkb': ['C44', 'D04'],
#   'ass': 'Ассоциация онкологов России, Общероссийская общественная организация "Ассоциация врачей-офтальмологов", Общероссийская общественная организация «Российское общество клинической онкологии», Ассоциация специалистов по проблемам меланомы',
#   'publish_date': '/Date(1584651600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '496_1',
#   'status': 0,
#   'db_id': 985,
#   'code': 496,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Острые лимфобластные лейкозы',
#   'Mkb': ['C91.0', 'C91.5', 'C91.7', 'C91.8', 'C91.9', 'C83.5', 'C83.7'],
#   'ass': 'Ассоциация онкологов России, Некоммерческое партнерство содействия развитию гематологии и трансплантологии костного мозга "Национальное гематологическое общество"\r\n',
#   'publish_date': '/Date(1584910800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '534_2',
#   'status': 0,
#   'db_id': 990,
#   'code': 534,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'Вторичное злокачественное новообразование головного мозга и мозговых оболочек',
#   'Mkb': ['C79.3'],
#   'ass': 'Ассоциация онкологов России, Ассоциация нейрохирургов России, Общероссийская общественная организация «Российское общество клинической онкологии»',
#   'publish_date': '/Date(1586466000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '575_1',
#   'status': 0,
#   'db_id': 991,
#   'code': 575,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Синдром Сезари',
#   'Mkb': ['C84.1'],
#   'ass': 'Российское профессиональное общество онкогематологов, Общероссийская общественная организация "Российское общество дерматовенерологов и косметологов"',
#   'publish_date': '/Date(1588107600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '586_1',
#   'status': 0,
#   'db_id': 993,
#   'code': 586,
#   'version': 1,
#   'ver': 2,
#   'age': 2,
#   'name': 'Острые миелоидные лейкозы',
#   'Mkb': ['C92.0',
#    'C92.3',
#    'C92.5',
#    'C92.6',
#    'C92.7',
#    'C92.8',
#    'C92.9',
#    'C93.0',
#    'C94.0',
#    'C94.2'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1589922000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '588_2',
#   'status': 0,
#   'db_id': 996,
#   'code': 588,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'Нейрогенная дисфункция нижних мочевыводящих путей',
#   'Mkb': ['G95.8', 'G83.4', 'N31.9', 'N31.8', 'N31.0', 'N31.1', 'N31.2'],
#   'ass': 'Общероссийская общественная организация "Российское общество урологов"',
#   'publish_date': '/Date(1590958800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '587_1',
#   'status': 0,
#   'db_id': 997,
#   'code': 587,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Почечная колика',
#   'Mkb': ['N23'],
#   'ass': 'Общероссийская общественная организация "Российское общество урологов"',
#   'publish_date': '/Date(1590958800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '73_3',
#   'status': 0,
#   'db_id': 999,
#   'code': 73,
#   'version': 3,
#   'ver': 2,
#   'age': 2,
#   'name': 'Меланома кожи и слизистых оболочек',
#   'Mkb': ['C43',
#    'C51',
#    'C60.9',
#    'C63.2',
#    'C69.0',
#    'C00',
#    'C26',
#    'C30',
#    'C32',
#    'C52',
#    'C53',
#    'C77',
#    'C78',
#    'C79',
#    'D03.0',
#    'D03.9',
#    'D22',
#    'Q82.5'],
#   'ass': 'Ассоциация онкологов России, Ассоциация специалистов по проблемам меланомы, Общероссийская общественная организация «Российское общество клинической онкологии», Национальное общество детских гематологов, онкологов, Общероссийская общественная организация "Российское общество детских онкологов"',
#   'publish_date': '/Date(1595797200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '129_2',
#   'status': 0,
#   'db_id': 1006,
#   'code': 129,
#   'version': 2,
#   'ver': 2,
#   'age': 3,
#   'name': 'Агрессивные нефолликулярные лимфомы – диффузная крупноклеточная В-клеточная лимфома, первичная медиастинальная В-клеточная лимфома, лимфома Беркитта',
#   'Mkb': ['C83.3', 'C83.7', 'C85.2', 'C91.8'],
#   'ass': 'Ассоциация онкологов России, Российское профессиональное общество онкогематологов, Национальное общество детских гематологов, онкологов, Некоммерческое партнерство содействия развитию гематологии и трансплантологии костного мозга "Национальное гематологическое общество"\r\n',
#   'publish_date': '/Date(1587675600000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '590_1',
#   'status': 0,
#   'db_id': 1007,
#   'code': 590,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Психические и поведенческие расстройства, вызванные употреблением психоактивных веществ. Абстинентное состояние (синдром отмены) с делирием',
#   'Mkb': ['F10.4', 'F13.4', 'F19.4'],
#   'ass': 'Ассоциация наркологов',
#   'publish_date': '/Date(1596574800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '589_2',
#   'status': 0,
#   'db_id': 1010,
#   'code': 589,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'Психические и поведенческие расстройства,  вызванные употреблением психоактивных веществ. Психотическое расстройство',
#   'Mkb': ['F10.5',
#    'F11.5',
#    'F12.5',
#    'F13.5',
#    'F14.5',
#    'F15.5',
#    'F16.5',
#    'F18.5',
#    'F19.5'],
#   'ass': 'Ассоциация наркологов',
#   'publish_date': '/Date(1596574800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '591_1',
#   'status': 0,
#   'db_id': 1011,
#   'code': 591,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Острая интоксикация психоактивными веществами',
#   'Mkb': ['F10.0',
#    'F11.0',
#    'F12.0',
#    'F13.0',
#    'F14.0',
#    'F15.0',
#    'F16.0',
#    'F17.0',
#    'F18.0',
#    'F19.0'],
#   'ass': 'Ассоциация наркологов',
#   'publish_date': '/Date(1596574800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '592_1',
#   'status': 0,
#   'db_id': 1013,
#   'code': 592,
#   'version': 1,
#   'ver': 2,
#   'age': 1,
#   'name': 'Психические и поведенческие расстройства, вызванные употреблением психоактивных веществ. Пагубное (с вредными последствиями) употребление',
#   'Mkb': ['F10.1',
#    'F11.1',
#    'F12.1',
#    'F13.1',
#    'F14.1',
#    'F15.1',
#    'F16.1',
#    'F17.1',
#    'F18.1',
#    'F19.1'],
#   'ass': 'Ассоциация наркологов',
#   'publish_date': '/Date(1596574800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '154_3',
#   'status': 0,
#   'db_id': 1016,
#   'code': 154,
#   'version': 3,
#   'ver': 2,
#   'age': 1,
#   'name': 'Острый коронарный синдром без подъема сегмента ST электрокардиограммы',
#   'Mkb': ['I20.0',
#    'I21.0',
#    'I21.1',
#    'I21.2',
#    'I21.3',
#    'I21.4',
#    'I21.9',
#    'I22.0',
#    'I22.1',
#    'I22.8',
#    'I22.9',
#    'I24.8',
#    'I24.9'],
#   'ass': 'Ассоциация сердечно-сосудистых хирургов России, Общероссийская общественная организация «Российское кардиологическое общество»',
#   'publish_date': '/Date(1597006800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применяется',
#   'prev_cr_id': None},
#  {'id': '594_1',
#   'status': 0,
#   'db_id': 1019,
#   'code': 594,
#   'version': 1,
#   'ver': 2,
#   'age': 2,
#   'name': 'Расстройства аутистического спектра',
#   'Mkb': ['F84.0', 'F84.1', 'F84.4', 'F84.5', 'F84.8', 'F84.9'],
#   'ass': 'Ассоциация психиатров и психологов за научно-обоснованную практику\r\n',
#   'publish_date': '/Date(1597266000000)/',
#   'NPC_approved': True,
# ...
#   'publish_date': '/Date(1720687803190)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '647_2',
#   'status': 0,
#   'db_id': 1480,
#   'code': 647,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'Выпадение женских половых органов',
#   'Mkb': ['N81.0',
#    'N81.1',
#    'N81.2',
#    'N81.3',
#    'N81.4',
#    'N81.5',
#    'N81.6',
#    'N81.8',
#    'N81.9',
#    'N99.3'],
#   'ass': 'Общероссийская общественная организация "Российское общество урологов", Российское общество акушеров-гинекологов',
#   'publish_date': '/Date(1720694992790)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '6_2',
#   'status': 0,
#   'db_id': 1481,
#   'code': 6,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'Доброкачественная гиперплазия предстательной железы',
#   'Mkb': ['N40'],
#   'ass': 'Общероссийская общественная организация "Российское общество урологов"',
#   'publish_date': '/Date(1720769365643)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '204_2',
#   'status': 0,
#   'db_id': 1482,
#   'code': 204,
#   'version': 2,
#   'ver': 2,
#   'age': 3,
#   'name': 'Аногенитальные (венерические) бородавки',
#   'Mkb': ['A63.0'],
#   'ass': 'Общероссийская общественная организация "Российское общество дерматовенерологов и косметологов", Российское общество акушеров-гинекологов, Общероссийская общественная организация "Ассоциация колопроктологов России", Межрегиональная общественная организация "Национальный альянс дерматовенерологов и косметологов"',
#   'publish_date': '/Date(1720774735897)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '387_3',
#   'status': 0,
#   'db_id': 1483,
#   'code': 387,
#   'version': 3,
#   'ver': 2,
#   'age': 3,
#   'name': 'Другие виды нарушения обмена аминокислот с разветвленной цепью (Метилмалоновая ацидемия /ацидурия)',
#   'Mkb': ['E71.1'],
#   'ass': 'Союз педиатров России, Ассоциация медицинских генетиков',
#   'publish_date': '/Date(1720780892567)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '787_1',
#   'status': 0,
#   'db_id': 1484,
#   'code': 787,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Увеиты неинфекционные',
#   'Mkb': ['H20.0',
#    'H20.1',
#    'H20.2',
#    'H20.8',
#    'H20.9',
#    'H22.1',
#    'H30',
#    'H30.0',
#    'H30.1',
#    'H30.2',
#    'H30.8',
#    'H30.9',
#    'H35.0',
#    'H40.4',
#    'H43.3',
#    'H44.1'],
#   'ass': 'Общероссийская общественная организация "Ассоциация врачей-офтальмологов", Общероссийская общественная организация «Общество офтальмологов России»',
#   'publish_date': '/Date(1720788714777)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '176_2',
#   'status': 0,
#   'db_id': 1485,
#   'code': 176,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'Болезнь Крона',
#   'Mkb': ['K50'],
#   'ass': 'Общероссийская общественная организация "Ассоциация колопроктологов России", Российская Гастроэнтерологическая Ассоциация',
#   'publish_date': '/Date(1721135981973)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '459_2',
#   'status': 0,
#   'db_id': 1486,
#   'code': 459,
#   'version': 2,
#   'ver': 2,
#   'age': 2,
#   'name': 'ВИЧ-инфекция у детей',
#   'Mkb': ['B20', 'B21', 'B22', 'B23', 'B24', 'R75', 'Z21', 'Z20.6'],
#   'ass': 'Национальная ассоциация специалистов по профилактике, диагностике и лечению ВИЧ-инфекции',
#   'publish_date': '/Date(1721218191243)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '670_2',
#   'status': 0,
#   'db_id': 1487,
#   'code': 670,
#   'version': 2,
#   'ver': 2,
#   'age': 3,
#   'name': 'Выкидыш (самопроизвольный аборт)',
#   'Mkb': ['O02',
#    'O02.0',
#    'O02.9',
#    'O03',
#    'O03.0',
#    'O03.1',
#    'O03.3',
#    'O03.6',
#    'O03.8',
#    'O03.9',
#    'O05',
#    'O05.0',
#    'O05.1',
#    'O05.3',
#    'O05.6',
#    'O05.8',
#    'O05.9',
#    'O20',
#    'O20.0',
#    'O20.9',
#    'N85.3',
#    'N85.7'],
#   'ass': 'Российское общество акушеров-гинекологов',
#   'publish_date': '/Date(1721226609880)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '482_2',
#   'status': 0,
#   'db_id': 1488,
#   'code': 482,
#   'version': 2,
#   'ver': 2,
#   'age': 3,
#   'name': 'Классическая фенилкетонурия и другие виды гиперфенилаланинемии',
#   'Mkb': ['E70.0', 'E70.1', 'E70.9'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России, Ассоциация Здоровье детей',
#   'publish_date': '/Date(1721293778310)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '788_1',
#   'status': 0,
#   'db_id': 1489,
#   'code': 788,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Недостаточность 3-метилкротонил-КоА карбоксилазы (3-метилкротонилглицинурия, метилкротонил КоА карбоксилазная недостаточность)',
#   'Mkb': ['E71.1'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России',
#   'publish_date': '/Date(1721299844127)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '789_1',
#   'status': 0,
#   'db_id': 1490,
#   'code': 789,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Недостаточность митохондриальной ацетоацетил-КоА-тиолазы (дефицит бета-кетотиолазы, дефицит Т2)',
#   'Mkb': ['E71.1'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России',
#   'publish_date': '/Date(1721307383333)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '318_2',
#   'status': 0,
#   'db_id': 1491,
#   'code': 318,
#   'version': 2,
#   'ver': 2,
#   'age': 3,
#   'name': 'Болезнь Фабри',
#   'Mkb': ['E75.2'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России',
#   'publish_date': '/Date(1721378774017)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '790_1',
#   'status': 0,
#   'db_id': 1492,
#   'code': 790,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Дефицит 3-гидрокси-3-метилглутарил-КоА лиазы',
#   'Mkb': ['E71.1'],
#   'ass': 'Ассоциация медицинских генетиков, Союз педиатров России',
#   'publish_date': '/Date(1721383355420)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '791_1',
#   'status': 0,
#   'db_id': 1493,
#   'code': 791,
#   'version': 1,
#   'ver': 2,
#   'age': 3,
#   'name': 'Послеродовые инфекционные осложнения',
#   'Mkb': ['O08.0',
#    'O75.3',
#    'O85',
#    'O86.0',
#    'O86.1',
#    'O86',
#    'O86.8',
#    'O90.0',
#    'O90.1',
#    'O90.2',
#    'O90.8',
#    'O90.9',
#    'O91.1',
#    'O99.5'],
#   'ass': 'Российское общество акушеров-гинекологов, Корпоративная некоммерческая организация "Ассоциация анестезиологов – реаниматологов", Ассоциация акушерских анестезиологов-реаниматологов\r\n',
#   'publish_date': '/Date(1721396875457)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '641_2',
#   'status': 0,
#   'db_id': 1495,
#   'code': 641,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'Женское бесплодие',
#   'Mkb': ['N97',
#    'N97.0',
#    'N97.1',
#    'N97.2',
#    'N97.3',
#    'N97.4',
#    'N97.8',
#    'N97.9',
#    'N98.0',
#    'N98.2',
#    'N98.3',
#    'N98.8',
#    'N98.9',
#    'Z31.1',
#    'Z31.2',
#    'Z31.3',
#    'Z31.4',
#    'Z31.5',
#    'Z31.6',
#    'Z31.8'],
#   'ass': 'Российское общество акушеров-гинекологов, ООО "Российская ассоциация репродукции человека (РАРЧ)"',
#   'publish_date': '/Date(1721631788617)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '79_2',
#   'status': 0,
#   'db_id': 1496,
#   'code': 79,
#   'version': 2,
#   'ver': 2,
#   'age': 1,
#   'name': 'ВИЧ-инфекция у взрослых',
#   'Mkb': ['B20',
#    'B21',
#    'B22',
#    'B23',
#    'B24',
#    'F02.4',
#    'R75',
#    'Z11.4',
#    'Z20.6',
#    'Z21',
#    'Z71.7',
#    'Z83.0'],
#   'ass': 'Национальная вирусологическая ассоциация., Московское онкологическое общество',
#   'publish_date': '/Date(1721640589403)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '660_2',
#   'status': 0,
#   'db_id': 1497,
#   'code': 660,
#   'version': 2,
#   'ver': 2,
#   'age': 2,
#   'name': 'Врожденная анемия вследствие кровопотери у плода и другие врожденные анемии новорожденных',
#   'Mkb': ['P61.3', 'P61.4'],
#   'ass': 'Общероссийская общественная организация содействия развитию неонатологии «Российское общество неонатологов», Ассоциация специалистов в области перинатальной медицины, оказания помощи беременной женщине и плоду, новорожденному и ребенку в возрасте до 3-х лет (АСПМ )',
#   'publish_date': '/Date(1721647505447)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '661_2',
#   'status': 0,
#   'db_id': 1498,
#   'code': 661,
#   'version': 2,
#   'ver': 2,
#   'age': 2,
#   'name': 'Ранняя анемия недоношенных',
#   'Mkb': ['P61.2'],
#   'ass': 'Общероссийская общественная организация содействия развитию неонатологии «Российское общество неонатологов», Ассоциация специалистов в области перинатальной медицины, оказания помощи беременной женщине и плоду, новорожденному и ребенку в возрасте до 3-х лет (АСПМ )',
#   'publish_date': '/Date(1721649432843)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '274_3',
#   'status': 0,
#   'db_id': 1499,
#   'code': 274,
#   'version': 3,
#   'ver': 2,
#   'age': 1,
#   'name': 'Запор',
#   'Mkb': ['K59.0'],
#   'ass': 'Российская Гастроэнтерологическая Ассоциация, Общероссийская общественная организация "Ассоциация колопроктологов России", Межрегиональная Общественная Организация "Научное сообщество по содействию клиническому изучению микробиома\xa0человека"',
#   'publish_date': '/Date(1721658022527)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '699_2',
#   'status': 0,
#   'db_id': 1500,
#   'code': 699,
#   'version': 2,
#   'ver': 2,
#   'age': 2,
#   'name': 'Иммунная тромбоцитопения',
#   'Mkb': ['D69.3'],
#   'ass': 'Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1721660994450)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '229_3',
#   'status': 0,
#   'db_id': 1501,
#   'code': 229,
#   'version': 3,
#   'ver': 2,
#   'age': 2,
#   'name': 'Ожирение у детей',
#   'Mkb': ['E66.0', 'E66.1', 'E66.2', 'E66.8', 'E66.9', 'E67.8'],
#   'ass': 'Российская ассоциация эндокринологов, Общество бариатрических хирургов',
#   'publish_date': '/Date(1721737810020)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '648_2',
#   'status': 0,
#   'db_id': 1502,
#   'code': 648,
#   'version': 2,
#   'ver': 2,
#   'age': 2,
#   'name': 'Преждевременное половое развитие',
#   'Mkb': ['E30.1', 'E30.8', 'E22.8', 'E28.1', 'E29.0', 'E31.1'],
#   'ass': 'Российская ассоциация эндокринологов',
#   'publish_date': '/Date(1721803902357)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '686_3',
#   'status': 0,
#   'db_id': 1503,
#   'code': 686,
#   'version': 3,
#   'ver': 2,
#   'age': 2,
#   'name': 'Тиреоидиты у детей',
#   'Mkb': ['E03.8', 'E06.0', 'E06.1', 'E06.3', 'E06.5', 'E06.9'],
#   'ass': 'Российская ассоциация эндокринологов',
#   'publish_date': '/Date(1721807548577)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '24_2',
#   'status': 0,
#   'db_id': 1504,
#   'code': 24,
#   'version': 2,
#   'ver': 2,
#   'age': 2,
#   'name': 'Другие сфинголипидозы (болезнь Гоше)',
#   'Mkb': ['E75.2'],
#   'ass': 'Союз педиатров России, Ассоциация медицинских генетиков, Национальное общество детских гематологов, онкологов',
#   'publish_date': '/Date(1721989204297)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '712_2',
#   'status': 0,
#   'db_id': 1505,
#   'code': 712,
#   'version': 2,
#   'ver': 2,
#   'age': 2,
#   'name': 'Врожденный гипотиреоз у детей',
#   'Mkb': ['E03.0', 'E03.1', 'E07.1', 'E07.8'],
#   'ass': 'Российская ассоциация эндокринологов',
#   'publish_date': '/Date(1721997100657)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '622_5',
#   'status': 0,
#   'db_id': 1506,
#   'code': 622,
#   'version': 5,
#   'ver': 2,
#   'age': 2,
#   'name': 'Сахарный диабет 2 типа у детей',
#   'Mkb': ['E11.2',
#    'E11.3',
#    'E11.4',
#    'E11.5',
#    'E11.6',
#    'E11.7',
#    'E11.8',
#    'E11.9',
#    'R73.0'],
#   'ass': 'Российская ассоциация эндокринологов',
#   'publish_date': '/Date(1722238047157)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено. Применяется ',
#   'prev_cr_id': '622_3'},
#  {'id': '246_3',
#   'status': 0,
#   'db_id': 1508,
#   'code': 246,
#   'version': 3,
#   'ver': 2,
#   'age': 3,
#   'name': 'Экзема ',
#   'Mkb': ['L30.0', 'L30.1', 'L30.2', 'L30.3', 'L30.9'],
#   'ass': 'Общероссийская общественная организация "Российское общество дерматовенерологов и косметологов"',
#   'publish_date': '/Date(1722286800000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '161_2',
#   'status': 0,
#   'db_id': 1509,
#   'code': 161,
#   'version': 2,
#   'ver': 2,
#   'age': 3,
#   'name': 'Психические и поведенческие расстройства,  вызванные употреблением психоактивных веществ Синдром зависимости от психоактивных веществ (кроме алкоголя и никотина)',
#   'Mkb': ['F11.2',
#    'F12.2',
#    'F13.2',
#    'F14.2',
#    'F15.2',
#    'F16.2',
#    'F18.2',
#    'F19.2'],
#   'ass': 'Общественная организация "Российское общество психиатров"',
#   'publish_date': '/Date(1722373200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '32_2',
#   'status': 0,
#   'db_id': 1510,
#   'code': 32,
#   'version': 2,
#   'ver': 2,
#   'age': 3,
#   'name': 'Психические и поведенческие расстройства, вызванные употреблением психоактивных веществ Синдром отмены психоактивных веществ (абстинентное состояние, вызванное употреблением психоактивных веществ) (кроме алкоголя и никотина)',
#   'Mkb': ['F11.3',
#    'F12.3',
#    'F13.3',
#    'F14.3',
#    'F15.3',
#    'F16.3',
#    'F18.3',
#    'F19.3'],
#   'ass': 'Общественная организация "Российское общество психиатров"',
#   'publish_date': '/Date(1722373200000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '174_3',
#   'status': 0,
#   'db_id': 1511,
#   'code': 174,
#   'version': 3,
#   'ver': 2,
#   'age': 1,
#   'name': 'Ангиодисплазия кишечника',
#   'Mkb': ['K55.2', 'K55.3', 'K55.8'],
#   'ass': 'Общероссийская общественная организация "Ассоциация колопроктологов России"',
#   'publish_date': '/Date(1722595911887)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '182_3',
#   'status': 0,
#   'db_id': 1512,
#   'code': 182,
#   'version': 3,
#   'ver': 2,
#   'age': 3,
#   'name': 'Идиопатический мегаколон',
#   'Mkb': ['K59.3'],
#   'ass': 'Общероссийская общественная организация "Ассоциация колопроктологов России"',
#   'publish_date': '/Date(1722546000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '183_3',
#   'status': 0,
#   'db_id': 1513,
#   'code': 183,
#   'version': 3,
#   'ver': 2,
#   'age': 1,
#   'name': 'Недостаточность анального сфинктера',
#   'Mkb': ['K62.8', 'R15'],
#   'ass': 'Общероссийская общественная организация "Ассоциация колопроктологов России"',
#   'publish_date': '/Date(1722606785313)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено',
#   'prev_cr_id': ''},
#  {'id': '185_3',
#   'status': 0,
#   'db_id': 1514,
#   'code': 185,
#   'version': 3,
#   'ver': 2,
#   'age': 3,
#   'name': 'Острый парапроктит',
#   'Mkb': ['K61', 'K61.0', 'K61.1', 'K61.2', 'K61.3', 'K61.4'],
#   'ass': 'Общероссийская общественная организация "Ассоциация колопроктологов России", Общероссийская общественная организация "Российская ассоциация детских хирургов"',
#   'publish_date': '/Date(1722546000000)/',
#   'NPC_approved': True,
#   'apply_status': 'Применение отложено. Применяется ',
#   'prev_cr_id': '185_1'}]

# %%
type(response)
# Out:
# list

# %%
response[0]
# Out:
# {'id': '66_3',
#  'status': 0,
#  'db_id': 10,
#  'code': 66,
#  'version': 3,
#  'ver': 1,
#  'age': 2,
#  'name': 'Рак носоглотки',
#  'Mkb': ['C11'],
#  'ass': 'Общероссийская общественная организация "Российское общество детских онкологов", Национальное общество детских гематологов, онкологов',
#  'publish_date': '/Date(1589835600000)/',
#  'NPC_approved': True,
#  'apply_status': 'Применяется',
#  'prev_cr_id': None}

# %%
response[1]
# Out:
# {'id': '68_1',
#  'status': 0,
#  'db_id': 11,
#  'code': 68,
#  'version': 1,
#  'ver': 1,
#  'age': 2,
#  'name': 'Гепатобластома',
#  'Mkb': ['C22.2'],
#  'ass': 'Национальное общество детских гематологов, онкологов',
#  'publish_date': '/Date(1589922000000)/',
#  'NPC_approved': True,
#  'apply_status': 'Применяется',
#  'prev_cr_id': None}

# %%
len(response)
# Out:
# 453

# %%
link = 'https://apicr.minzdrav.gov.ru/api.ashx?op=GetJsonClinrecs&ssid=undefined'
response = req.get(link).text
soup = BeautifulSoup(response, 'lxml')
# df_clin = pd.read_xml
# df_clin = pd.read_xml(StringIO(soup))
# soup
# df_clin = pd.read_xml(soup, parser= 'lxml')
# df_clin
StringIO()?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a52cbde3706b> in <cell line: 9>()
#       7 # df_clin = pd.read_xml(soup, parser= 'lxml')
#       8 # df_clin
# ----> 9 StringIO(soup)
#
# TypeError: initial_value must be str or None, not BeautifulSoup

# %%
StringIO()?
# Out:
#   File "<ipython-input-43-ee4403f5f9c1>", line 1
#     StringIO()?
#               ^
# SyntaxError: invalid syntax

# %%
import time
import requests
import pandas as pd

# %%
data_folder = '/content/sample_data'
url_base = 'https://api.socio.center/public/priority'
url_list = f"{url_base}/list"
university_list_resp = requests.get(url_list)
university_list = pd.DataFrame()

if university_list_resp.status_code == 200:
    university_list_json_data = university_list_resp.json()

    if university_list_json_data['status'] == 'success':
        university_list = pd.DataFrame(university_list_json_data['data']['participants'])
        university_list['group'] = university_list['group'].apply(lambda x: university_list_json_data['data']['group'][x])

        # Сохраняем полученный список университетов
        university_list.to_csv(f"{data_folder}/university_list.csv", index=False)
        university_list.to_excel(f"{data_folder}/university_list.xlsx", index=False)
else:
    raise Exception(f"{url_list} return status code {university_list_resp.status_code}")

# Выводим первые 10 записей
university_list.head(10)

# %%
url_base = 'https://cr.minzdrav.gov.ru/clin_recomend'
url_list = f"{url_base}/list"
university_list_resp = requests.get(url_list).content
# university_list_resp.headers
university_list_resp
# Out:
# b'<!DOCTYPE html><html lang=en><head><base href=/ ><meta charset=utf-8><meta http-equiv=X-UA-Compatible content="IE=edge"><meta name=viewport content="width=device-width,initial-scale=1"><link rel=icon href=/favicon.ico><title>\xd0\xa0\xd1\x83\xd0\xb1\xd1\x80\xd0\xb8\xd0\xba\xd0\xb0\xd1\x82\xd0\xbe\xd1\x80 \xd0\x9a\xd0\xa0</title><script src=/jquery-3.7.1.min.js></script><link href=/css/chunk-06739099.e2669fd2.css rel=prefetch><link href=/css/chunk-06c8bd4a.cca13a49.css rel=prefetch><link href=/css/chunk-0761f15f.e9124dc2.css rel=prefetch><link href=/css/chunk-0878a52e.ca30124f.css rel=prefetch><link href=/css/chunk-12e3b99a.5a4fd7ef.css rel=prefetch><link href=/css/chunk-13e1c7b6.d250570e.css rel=prefetch><link href=/css/chunk-1bdd8c04.bb8d7c6b.css rel=prefetch><link href=/css/chunk-25b730f6.1dfe4448.css rel=prefetch><link href=/css/chunk-26f01824.8689fec2.css rel=prefetch><link href=/css/chunk-2c95bb2c.5943f77f.css rel=prefetch><link href=/css/chunk-2da04520.476a19eb.css rel=prefetch><link href=/css/chunk-37b0c584.85c0c9e4.css rel=prefetch><link href=/css/chunk-3dc2c37a.ff9d04c9.css rel=prefetch><link href=/css/chunk-4cd97834.16fdebd0.css rel=prefetch><link href=/css/chunk-50b274ea.7121ccb9.css rel=prefetch><link href=/css/chunk-5acd87c8.1af87833.css rel=prefetch><link href=/css/chunk-623c24a0.ae2fcc9d.css rel=prefetch><link href=/css/chunk-685e02d9.ebc6360c.css rel=prefetch><link href=/css/chunk-6e5aa230.cbfe0a98.css rel=prefetch><link href=/css/chunk-764b4158.17bc742a.css rel=prefetch><link href=/css/chunk-77cede33.2d89237b.css rel=prefetch><link href=/css/chunk-7893dae4.19ca89fe.css rel=prefetch><link href=/css/chunk-79573d14.7c2a1d7e.css rel=prefetch><link href=/css/chunk-832e91fa.ab9d5297.css rel=prefetch><link href=/css/chunk-8c2e39a4.f0893a86.css rel=prefetch><link href=/css/chunk-976f1a42.e0fd3476.css rel=prefetch><link href=/css/chunk-aaba0338.f9e13a56.css rel=prefetch><link href=/css/chunk-ca046386.bd9dffc5.css rel=prefetch><link href=/css/chunk-f0a4cade.910002fd.css rel=prefetch><link href=/js/chunk-06739099.f48728da.js rel=prefetch><link href=/js/chunk-06c8bd4a.9a23ef92.js rel=prefetch><link href=/js/chunk-0761f15f.36bf34db.js rel=prefetch><link href=/js/chunk-0878a52e.987ce8d7.js rel=prefetch><link href=/js/chunk-12e3b99a.233ddca3.js rel=prefetch><link href=/js/chunk-13e1c7b6.be37e51f.js rel=prefetch><link href=/js/chunk-1bdd8c04.3a77e221.js rel=prefetch><link href=/js/chunk-22f4fbe2.799cf74b.js rel=prefetch><link href=/js/chunk-25b730f6.821fc327.js rel=prefetch><link href=/js/chunk-26f01824.6cd78648.js rel=prefetch><link href=/js/chunk-2c95bb2c.1b7baf8b.js rel=prefetch><link href=/js/chunk-2da04520.5fb0a492.js rel=prefetch><link href=/js/chunk-37b0c584.07f6dd46.js rel=prefetch><link href=/js/chunk-3dc2c37a.e38baf73.js rel=prefetch><link href=/js/chunk-3e3aa41c.757114cb.js rel=prefetch><link href=/js/chunk-4cd97834.9ca36181.js rel=prefetch><link href=/js/chunk-50b274ea.2eee7426.js rel=prefetch><link href=/js/chunk-58f606dc.553a9207.js rel=prefetch><link href=/js/chunk-5acd87c8.297f9b1c.js rel=prefetch><link href=/js/chunk-623c24a0.2d0403ab.js rel=prefetch><link href=/js/chunk-685e02d9.9c95f57a.js rel=prefetch><link href=/js/chunk-6df0c686.8719dcc5.js rel=prefetch><link href=/js/chunk-6e5aa230.d57d6c92.js rel=prefetch><link href=/js/chunk-764b4158.e855d9be.js rel=prefetch><link href=/js/chunk-77cede33.1b3b522f.js rel=prefetch><link href=/js/chunk-7893dae4.47cbc231.js rel=prefetch><link href=/js/chunk-79573d14.ee782bdf.js rel=prefetch><link href=/js/chunk-832e91fa.d5aca093.js rel=prefetch><link href=/js/chunk-8c2e39a4.020940d2.js rel=prefetch><link href=/js/chunk-976f1a42.3eb6c13d.js rel=prefetch><link href=/js/chunk-aaba0338.3a34e08f.js rel=prefetch><link href=/js/chunk-ca046386.08537c06.js rel=prefetch><link href=/js/chunk-f0a4cade.8706725e.js rel=prefetch><link href=/css/app.df7fa259.css rel=preload as=style><link href=/css/chunk-vendors.4269c83b.css rel=preload as=style><link href=/js/app.a42fad0f.js rel=prelo ...

# %%
url_base = 'https://cr.minzdrav.gov.ru/clin_recomend'
url_list = f"{url_base}/list"
university_list_resp = requests.get(url_list)
# university_list_resp.headers
university_list_resp.json()

# %%
r = requests.get('https://cr.minzdrav.gov.ru/clin_recomend')
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-25-cfe8d3be58ac> in <cell line: 2>()
#       1 r = requests.get('https://cr.minzdrav.gov.ru/clin_recomend')
# ----> 2 r.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# r = requests.get('https://api.github.com/events')
# r.json()

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Добро пожаловать в Colab!</h1>
# </div>
#
# <div class="markdown-google-sans">
#   <h2>&#40;Новое&#41; Попробуйте Gemini API</h2>
#   <ul>
#   <li><a href="https://makersuite.google.com/app/apikey">Generate a Gemini API key</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/google/generative-ai-docs/blob/main/site/en/tutorials/quickstart_colab.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API: Quickstart with Python</a></li>
#   <li><a href="https://colab.research.google.com/notebooks/snippets/gemini.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API code sample</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %% [markdown]
# Уже знакомы с Colab? В этом видео рассказывается о функциях, которые вы могли пропустить: интерактивных таблицах, истории выполненного кода и палитре команд.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Значок видео с изображением трех полезных функций Google Colab' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>Что такое Colab?</h2>
# </div>
#
# Colaboratory, или просто Colab, позволяет писать и выполнять код Python в браузере. При этом:
# - не требуется никакой настройки;
# - бесплатный доступ к графическим процессорам;
# - предоставлять доступ к документам другим людям очень просто.
#
# Это отличное решение для <strong>студентов</strong>, <strong>специалистов по обработке данных</strong> и <strong>исследователей в области искусственного интеллекта</strong>. Чтобы узнать больше, посмотрите <a href="https://www.youtube.com/watch?v=inN8seMm7UI">ознакомительное видео</a> или начните работу с инструментом ниже.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Начало работы</strong>
# </div>
#
# Документ, который вы читаете, размещен не на статической веб-странице, а в интерактивной среде под названием <strong>блокнот Colab</strong>, позволяющей писать и выполнять код.
#
# Например, вот <strong>ячейка</strong> с коротким скриптом Python, который позволяет рассчитать значение, выразить его в виде переменной и распечатать результат:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Чтобы выполнить код в ячейке выше, выберите ее, а затем нажмите кнопку воспроизведения слева от кода или используйте сочетание клавиш Cmd/Ctrl + Ввод. Чтобы изменить код, достаточно нажать на ячейку.
#
# Переменные, заданные в одной ячейке, можно будет использовать в других ячейках:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Благодаря блокнотам Colab вы можете использовать в одном документе <strong>исполняемый код</strong>, <strong>форматированный текст</strong>, <strong>изображения</strong>, <strong>разметку HTML</strong>, <strong>набор LaTeX</strong> и не только. Блокноты Colab будут храниться на вашем Google Диске. Вы сможете открыть к ним доступ коллегам или друзьям, разрешив им просматривать или даже редактировать документ, а также оставлять комментарии. Подробная информация доступна на <a href="/notebooks/basic_features_overview.ipynb">этой странице</a>. Чтобы создать блокнот Colab, можно воспользоваться меню "Файл" выше или <a href="http://colab.research.google.com#create=true">перейти по этой ссылке</a>.
#
# Блокноты Colab – это блокноты Jupyter, которые размещены в сервисе Colab. Подробная информация о проекте Jupyter доступна на сайте <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Анализ и обработка данных
# </div>
#
# Colab позволяет использовать для анализа и визуализации данных все возможности популярных библиотек Python. Например, в ячейке ниже используется библиотека <strong>numpy</strong> для генерации случайных данных, а также библиотека <strong>matplotlib</strong> для их визуализации. Чтобы изменить код, достаточно нажать на ячейку.

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Вы можете импортировать в блокноты Colab данные из своего аккаунта Google Диска, в том числе из таблиц, а также из GitHub и многих других источников. Чтобы узнать больше об импорте данных и о том, как можно использовать Colab для их анализа и обработки, изучите ссылки в разделе <a href="#working-with-data">Работа с данными</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Машинное обучение
# </div>
#
# В Colab вы можете импортировать набор данных изображения, сориентировать на него классификатор изображений и оценить модель с помощью <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">нескольких строк кода</a>. Код в блокнотах Colab исполняется на облачных серверах Google. Это означает, что вы можете использовать аппаратное обеспечение Google, <a href="#using-accelerated-hardware">в том числе графические процессоры и TPU</a>, независимо от мощности вашей машины. Вам нужен только браузер.

# %% [markdown]
# Colab активно используется в области машинного обучения, в том числе для:
# - знакомства с TensorFlow;
# - разработки и обучения нейронных сетей;
# - экспериментов с TPU;
# - распространения исследований в области ИИ;
# - создания руководств.
#
# Примеры использования блокнотов Colab в сфере машинного обучения приведены в разделе <a href="#machine-learning-examples">Примеры использования в машинном обучении</a> ниже.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Ресурсы по теме
#
# ### Работа с блокнотами в Colab
#
# </div>
#
# - [Общие сведения о Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Руководство для Markdown](/notebooks/markdown_guide.ipynb)
# - [Импорт библиотек и установка зависимостей](/notebooks/snippets/importing_libraries.ipynb)
# - [Сохранение и загрузка блокнотов в GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Интерактивные формы](/notebooks/forms.ipynb)
# - [Интерактивные виджеты](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Работа с данными
# </div>
#
# - [Загрузка данных: Диск, Таблицы и Google Cloud Storage](/notebooks/io.ipynb)
# - [Диаграмма: визуализация данных](/notebooks/charts.ipynb)
# - [Начало работы с BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Экспресс-курс по машинному обучению
#
# <div>
#
# Вот несколько блокнотов из онлайн-курса по машинному обучению от Google. Ещё больше информации доступно на <a href="https://developers.google.com/machine-learning/crash-course/">сайте курса</a>.
# - [Знакомство с Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Линейная регрессия в tf.keras с использованием синтетических данных](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Использование ускорителей
# </div>
#
# - [TensorFlow с графическими процессорами](/notebooks/gpu.ipynb)
# - [TensorFlow с TPU](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Примеры
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo Voice Swap</a>. Инструменты разговорного AI Nvidia NeMo позволяют использовать в аудиозаписи сгенерированный компьютером голос вместо человеческого.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Обучение классификатора изображений</a>. Используя предварительно обученный классификатор изображений, создайте модель Keras для распознавания цветов.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Классификация текста</a>. Разделите отзывы на сайте IMDb на <em>положительные</em> и <em>отрицательные</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Перенос стиля</a>. Используйте модель глубокого обучения, чтобы переносить стиль с одного изображения на другое.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Вопросно-ответный универсальный многоязычный кодировщик</a>. Используйте модель машинного обучения, чтобы отвечать на вопросы из набора данных SQuAD.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Интерполяция видео.</a> Спрогнозируйте, что произошло между первым и последним кадрами видео.
