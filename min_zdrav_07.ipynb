# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximTislenko/Acspect_patronum/blob/main/min_zdrav_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = 'https://apicr.minzdrav.gov.ru/api.ashx?op=GetClinrecPdf&id=812_1'
response = requests.get(url)

with open('812_1.pdf', 'wb') as file:
    file.write(response.content)

# %%
# https://apicr.minzdrav.gov.ru/api.ashx?op=GetClinrecPdf&id=359_3

# %%
id = '359_3'
url = 'https://apicr.minzdrav.gov.ru/api.ashx?op=GetClinrecPdf&id=' + id
response = requests.get(url)

with open(id +'.pdf', 'wb') as file:
    file.write(response.content)

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
# !pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Downloading pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 40.7 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20240706

# %%
import pdfminer

# %%
from pdfminer.high_level import extract_text
text = extract_text('/content/359_3.pdf')
# print(repr(text))

# print(text)

index = text.find("Лабораторные диагностические исследования")
print(index)
# Out:
# 2902

# %%
print(text[2902:2943])
# Out:
# Лабораторные диагностические исследования

# %%
marker = 'Инструментальные диагностические исследования'
pos_lab = text.find(marker,text.find(marker)+1)
pos_lab
# Out:
# 79564

# %%
marker = 'Лабораторные диагностические исследования'
pos_lab = text.find(marker,text.find(marker)+1)
pos_lab
# Out:
# 63107

# %%
def issled (text, per_list):
  pos_lab_start = text.find(per_list[0], text.find(per_list[0])+1)
  pos_lab_end = text.find(per_list[1], text.find(per_list[1])+1)
  text_lab = text[pos_lab_start + 41  : pos_lab_end - 5 ]
  # print(text_lab)
  return text_lab

per_list = ['Лабораторные диагностические исследования', 'Инструментальные диагностические исследования']

issled (text, per_list)
# Out:
# "\n\n•  Рекомендуется  проведение  исследования  общего  (клинического)  анализа \n\nкрови развернутого  пациентам при установке диагноза БА, в период тяжелого \n\nобострения  БА,  перед  проведением  аллерген-специфической  иммунотерапии, \n\nперед  назначением  генно-инженерной  иммунобиологической  терапии  и  в \n\nпродолжении  проведения  таргетной  терапии  с  целью  вы явления  возможного \n\nповышения  уровня  эозинофилов  или  вы явления  маркеров  инфекционного \n\nвоспаления  с  целью дифференциальной диагностики  с другой  патологией или \n\nвы явления  осложнений  для  определения  тактики  терапии,  или  с  целью \n\nисключения  противопоказаний  для  проведения  аллерген-специфической \n\nиммунотерапии,  или  для  выбора  препарата  таргетной  терапии  и  контроля \n\nбезопасности проводимого лечения [21,43-48].\n\nУровень убедительности рекомендаций -С (уровень достоверности доказательств - 5) \n\nКомментарии:  Повышение  уровня  эозинофипов  возможно  в  период  обострения \n\nБА.  Вместе  с  тем  эозинофшия  периферической  крови  может  иметь  другие  причины\n\n29\n\n\x0c(паразитарные  инвазии,  грибковая  инфекция  и  др.),  а уровень  эозинофшов до  450  кл/мкл \n\nявляется  вариантом  нормы.  Нормальный уровень  эозинофшов  периферической  крови  не \n\nявляется  доказательством  отсутствия  БА.  Необходимо  также  учитывать,  что  на \n\nданный  параметр  влияет  прием  некоторых  медикаментов  (прием  антигистаминных \n\nсредств  системного  действия,  антагонистов  лейкотриеновых  рецепторов  (КОЗВС: \n\nБлокаторы лейкотриеновых рецепторов)  и  системных глюкокортикостероидов  (Н02АВ: \n\nГлюкокортикоиды),  терапия  анти-ИЛ5  и  анти-ИЛ5К  моноклональными  антителами \n\nможет  приводить  к  снижению уровня  эозинофшии  периферической  крови).  Повышение \n\nуровня маркеров  бактериального  воспаления  (лейкоцитоз,  сдвиг лейкоцитарной формулы \n\nвлево)  является  поводом  для  поиска  очага  инфекционного  воспаления  (инфекции  верхних \n\nдыхательных  путей,  бронхит,  пневмония  и  др.).  Низкий  уровень  гемоглобина  может \n\nсвидетельствовать  о  железодефицитной анемии,  одним  из  симптомов  которой,  также \n\nкак и для БА, является одышка.  Повышение уровня гемоглобина может наблюдаться при \n\nХДН,  носит компенсаторный характер на фоне хронической гипоксемии,  ассоциировано с \n\nвторичным \n\nэритроцитозом \n\nи \n\nгипервязкостью, \n\nкоторые  могут \n\nнарушать \n\nмикроциркуляцию и ухудшать течение заболевания.\n\nЧастота исследования в динамике определяется индивидуально.\n\nЭозинофжы  периферической  крови  в  настоящее  время  используют  такэюе  в \n\nкачестве  биомаркера  при  определении  фенотипа  БА \n\n(косвенный  показатель \n\nэозинофшьного воспаления дыхательных путей),  индикатора ответа на терапию ИГКС, \n\nСГКС  и  ГИБП.  Характерными  биомаркерами  эозинофшьного  эндотипа  тяжелой \n\nбронхишьной  астмы \n\n(ТБА)  на  сегодняшний  день  принято  считать:  количество \n\nэозинофшов  в  периферической  крови  >  150  кл/мкл  и/ши  количество  эозинофшов  в \n\nмокроте  >  3%,  и/ши уровень  оксида  азота  выдыхаемого  воздуха  (РеЫО)  >  20 ррЪ  [49]. \n\nПри  этом  необходимо учитывать,  что  применение  системных  глюкокортикостероидов \n\n(Н02АВ:  Глюкокортикоиды)  и  анти-ИЛ5  и,  особенно,  анти-ИЛ5К  (Ш ЗВХ  «Прочие \n\nсредства  системного  действия  для  леченш  обструктивных  заболеваний  дыхательных \n\nпутей»)  приводит  к резкому  и продолжительному снижению  количества эозинофшов.  В \n\nданном \n\nслучае \n\nподтверэ/сдение \n\nэозинофшьного  типа \n\nвоспаления \n\nпроводится \n\nретроспективно,  при  наличии  анамнестических  данных  до  примененш  этих  классов \n\nпрепаратов.  В  свою  очередь,  крайне  высокий уровень  эозинофшии  (более  1500  кл/мкл) \n\nтребует  исключенш  иных  причин \n\n(наличия \n\nэозинофшьного \n\nгранулематоза  с \n\nполиангиитом  (ЭГПА),  гиперэозинофшьного  синдрома,  и  др.  вариантов  онкопатологии, \n\nаллергического бр ...

# %%
print(text_lab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-5cf1740f6f14> in <cell line: 1>()
# ----> 1 print(text_lab)
#
# NameError: name 'text_lab' is not defined

# %%
print(text[63107:79563])
# Out:
# Лабораторные диагностические исследования
#
# •  Рекомендуется  проведение  исследования  общего  (клинического)  анализа
#
# крови развернутого  пациентам при установке диагноза БА, в период тяжелого
#
# обострения  БА,  перед  проведением  аллерген-специфической  иммунотерапии,
#
# перед  назначением  генно-инженерной  иммунобиологической  терапии  и  в
#
# продолжении  проведения  таргетной  терапии  с  целью  вы явления  возможного
#
# повышения  уровня  эозинофилов  или  вы явления  маркеров  инфекционного
#
# воспаления  с  целью дифференциальной диагностики  с другой  патологией или
#
# вы явления  осложнений  для  определения  тактики  терапии,  или  с  целью
#
# исключения  противопоказаний  для  проведения  аллерген-специфической
#
# иммунотерапии,  или  для  выбора  препарата  таргетной  терапии  и  контроля
#
# безопасности проводимого лечения [21,43-48].
#
# Уровень убедительности рекомендаций -С (уровень достоверности доказательств - 5)
#
# Комментарии:  Повышение  уровня  эозинофипов  возможно  в  период  обострения
#
# БА.  Вместе  с  тем  эозинофшия  периферической  крови  может  иметь  другие  причины
#
# 29
#
# (паразитарные  инвазии,  грибковая  инфекция  и  др.),  а уровень  эозинофшов до  450  кл/мкл
#
# является  вариантом  нормы.  Нормальный уровень  эозинофшов  периферической  крови  не
#
# является  доказательством  отсутствия  БА.  Необходимо  также  учитывать,  что  на
#
# данный  параметр  влияет  прием  некоторых  медикаментов  (прием  антигистаминных
#
# средств  системного  действия,  антагонистов  лейкотриеновых  рецепторов  (КОЗВС:
#
# Блокаторы лейкотриеновых рецепторов)  и  системных глюкокортикостероидов  (Н02АВ:
#
# Глюкокортикоиды),  терапия  анти-ИЛ5  и  анти-ИЛ5К  моноклональными  антителами
#
# может  приводить  к  снижению уровня  эозинофшии  периферической  крови).  Повышение
#
# уровня маркеров  бактериального  воспаления  (лейкоцитоз,  сдвиг лейкоцитарной формулы
#
# влево)  является  поводом  для  поиска  очага  инфекционного  воспаления  (инфекции  верхних
#
# дыхательных  путей,  бронхит,  пневмония  и  др.).  Низкий  уровень  гемоглобина  может
#
# свидетельствовать  о  железодефицитной анемии,  одним  из  симптомов  которой,  также
#
# как и для БА, является одышка.  Повышение уровня гемоглобина может наблюдаться при
#
# ХДН,  носит компенсаторный характер на фоне хронической гипоксемии,  ассоциировано с
#
# вторичным
#
# эритроцитозом
#
# и
#
# гипервязкостью,
#
# которые  могут
#
# нарушать
#
# микроциркуляцию и ухудшать течение заболевания.
#
# Частота исследования в динамике определяется индивидуально.
#
# Эозинофжы  периферической  крови  в  настоящее  время  используют  такэюе  в
#
# качестве  биомаркера  при  определении  фенотипа  БА
#
# (косвенный  показатель
#
# эозинофшьного воспаления дыхательных путей),  индикатора ответа на терапию ИГКС,
#
# СГКС  и  ГИБП.  Характерными  биомаркерами  эозинофшьного  эндотипа  тяжелой
#
# бронхишьной  астмы
#
# (ТБА)  на  сегодняшний  день  принято  считать:  количество
#
# эозинофшов  в  периферической  крови  >  150  кл/мкл  и/ши  количество  эозинофшов  в
#
# мокроте  >  3%,  и/ши уровень  оксида  азота  выдыхаемого  воздуха  (РеЫО)  >  20 ррЪ  [49].
#
# При  этом  необходимо учитывать,  что  применение  системных  глюкокортикостероидов
#
# (Н02АВ:  Глюкокортикоиды)  и  анти-ИЛ5  и,  особенно,  анти-ИЛ5К  (Ш ЗВХ  «Прочие
#
# средства  системного  действия  для  леченш  обструктивных  заболеваний  дыхательных
#
# путей»)  приводит  к резкому  и продолжительному снижению  количества эозинофшов.  В
#
# данном
#
# случае
#
# подтверэ/сдение
#
# эозинофшьного  типа
#
# воспаления
#
# проводится
#
# ретроспективно,  при  наличии  анамнестических  данных  до  примененш  этих  классов
#
# препаратов.  В  свою  очередь,  крайне  высокий уровень  эозинофшии  (более  1500  кл/мкл)
#
# требует  исключенш  иных  причин
#
# (наличия
#
# эозинофшьного
#
# гранулематоза  с
#
# полиангиитом  (ЭГПА),  гиперэозинофшьного  синдрома,  и  др.  вариантов  онкопатологии,
#
# аллергического бронхолегочного аспергшеза (АБЛА)  и др.).
#
# 30
#
# В  свою  очередь,  применение  анти-ИЛ4Р  моноклональных  антител  (дупилумаб**,
#
# Н11АН  «Препараты  для  лечения  дерматита,  кроме  кортикостероидов»)  может
#
# приводить  к  росту  количества  оозинофилов  периферической  крови,  в  большинстве
#
# случаев  клинически  незначимому.  Однако,  с  учетом  хоть  и  очень  редких,  но  описанных
#
# случаев  стремительного  роста  количества  оозинофилов  до  крайне  высоких  значений
#
# (выше  5000  кл/мкл),  в  процессе  терапии  дупилумабом**  необходимо  регулярно
#
# мониторировать  уровень  оозинофилов  периферической  крови  с  оценкой  клинических
#
# исходов.
#
# Необходимо учитывать возрастные особенности,  так,  если у  взрослых пациентов
#
# с  БА  периферическая  оозинофилия  и  оозинофилия  дыхательных  путей  коррелируют
#
# между  собой,  то у  детей,  в  особенности  дошкольного  возраста,  согласно  проведенному
#
# исследованию  [48]  при  абсолютном  значении  оозинофилов  менее  100  кл/мл  может
#
# отмечаться  выраженное  воспаление  дыхательных  путей,  в  то  э/се  время  оозинофилия
#
# может  диагностироваться  у   некоторых  здоровых  детей  [47].  Также,  для  детской
#
# популяции  в  числе  причин  оозинофилии  периферической  крови  чаще,  чем  у   взрослых,
#
# выявляются  различные  паразитарные  инфекции  (аскаридоз,  анизакидоз,  токсокароз,
#
# стронгиллоидоз и др.  (с учетом ондемичности региона проживания и пищевых привычек),
#
# для
#
# диагностики
#
# которых
#
# возможно
#
# выполнение  молекулярно-биологического
#
# исследования  фекалий  на  соответствующего  возбудителя  (Молекулярно-биологическое
#
# исследование  фекалий  на  аскариды  (Азсаггз  ЫтЪпсоШез),  Молекулярно-биологическое
#
# исследование  фекалий  на  возбудителя  описторхоза  (ОрШНогсМз /еПпеш)  Молекулярно­
#
# биологическое  исследование  фекалий  на  возбудителя  стронгиллоидоза  (81гоп§у1оШез
#
# з(егсогаШ)),  определение ДНК соответствующего возбудителя в фекалиях методом ПЦР
#
# (Определение ДН К аскарид  (Азсапз 1итЪпсоШез)  в фекалиях методом ПЦР,  Определение
#
# Д Н К   возбудителя  описторхоза  (ОрШНогсЫз  /еИпеиз)  в  фекалиях  методом  ПЦР,
#
# Определение  ДНК  возбудителя  стронгиллоидоза  (8(гопуу1ок1е$  МегсогаИз)  в  фекалиях
#
# методом  ПЦР),  а  также  выявление  антител  классов  ДЕ,  ДМ,  Д О   к  данным
#
# возбудителям  (Определение  антител  к  токсокаре  собак  (Тохосага  сатз)  в  крови,
#
# Определение  антител  к  возбудителю  описторхоза  (ОрШНогсЫз  /еПпеиз)  в  крови
#
# Определение  антител  к  аскаридам  (Азсапз  1итЪпсоШез)  Определение  антител  к
#
# возбудителям стронгиллоидоза ($1гопру1оШез з1егсогаИз).
#
# •  Рекомендуется
#
# проведение
#
# цитологического
#
# исследования
#
# мокроты
#
# пациентам с гиперпродукцией мокроты или в период тяжелого обострения БА
#
# 31
#
# и  перед  назначением  генно-инженерной  иммунобиологической  терапин  с
#
# целью  выявления
#
# эозннофилии  мокроты,  или  вы явления  маркеров
#
# инфекционного  воспаления,  или  обнаружения  мицелия  грибов  с  целью
#
# определения  фенотипа  БА,  дифференциальной  диагностики  с  другой
#
# патологией нижних дыхательных путей [50-54].
#
# Уровень убедительности рекомендаций -В (уровень достоверности доказательств -  1)
#
# Комментарии:  оозинофилия  мокроты  >3%  является  одним  из  биомаркеров
#
# эозинофильного  воспаления  (см.  комментарий  выше),  характерного  наряду  с  другими
#
# признаками  для  эозинофильного  фенотипа  БА  [50-54].  Вместе  с  тем  эозинофилия
#
# мокроты  может  иметь  другие  причины
#
# (ЭГПА,  АБЛА,  микозы).  У  пациентов,
#
# получающих  ИГКС  в  качестве  базисной  терапии,  сохраняющаяся  высокая  эозинофилия
#
# мокроты
#
# (50-70%  и  более)  свидетельствует  о  недостаточном  эффекте  ИГКС
#
# (возможно  в  результате  неправильного  использования  устройства  для  ингаляции  или
#
# низкого  комплаенса),  а  также  является  неблагоприятным  фактором,  увеличивающим
#
# риск последующих обострений [55].
#
# •  Рекомендуется  исследование  уровня  общего  иммуноглобулина  Е  в  крови
#
# пациентам  при  установке диагноза  БА,  перед  назначением  генно-инженерной
#
# иммунобиологической  терапии  с  целью  определения  фенотипа заболевания,  а
#
# также  для  определения  показаний  (в  случае  необходимости)  к   терапии
#
# омализумабом**,  определения  его  терапевтической  дозы  и  выбора  режима
#
# терапии  [56,57].
#
# Уровень убедительности рекомендаций -С (уровень достоверности доказательств - 4)
#
# Комментарии:  Нормальный  или  повышенный  уровень  общего  1§Е  в  сыворотке
#
# крови не является доказательством отсутствия или наличия аллергического заболевания,
#
# в  том  числе  аллергического  (атопического)  фенотипа  БА.  Нормальный уровень  общего
#
# 1§Е может сочетаться с повышенным уровнем специфических 1$Е к причинно-значимым
#
# аллергенам,  в  то  же  время  повышенный  уровень  общего  1уЕ  может  наблюдаться  в
#
# отсутствии сенсибилизации и атопии (иными причинами повышенного уровня общего 1уЕ
#
# могут  быть  паразитарная  инвазия,  грибковая  инфекция,  онкопатология,  гипер-1§Е
#
# синдром и др.).
#
# Эффект  омализумаба**  реализуется  при  максимальном  связывании  свободного
#
# 1уЕ.  Расчет  дозы  омализумаба  и  определение  режима  терапии  осуществляют
#
# 32
#
# индивидуально,  при  наличии  показаний,  в  зависимости  от  массы  тела  и  исходного  (до
#
# первого введения омализумаба**) уровня общего 1§Е [56,57].
#
# •  Рекомендуется  исследование  уровня  антител  к  антигенам  растительного,
#
# животного  и  химического  происхождения
#
# в  крови  (определение  уровня
#
# аллерген-специфических  1§Е  антител)  пациентам  при  первичной диагностике
#
# БА,  в  процессе динамического  наблюдения  и  при  наличии  противопоказаний
#
# или  иных  причин,  препятствующих  проведению  кожно'го  тестирования
#
# (Накожные  исследования  реакции  на  аллергены),  сомнительных  результатах
#
# кожного тестирования, расхождении данных, полученных при сборе анамнеза,
#
# с результатами кожного тестирования с целью подтверждения аллергического
#
# фенотипа  БА,  вы явления  причинно-значимых аллергенов  с целью  выработки
#
# рекомендаций  по  образу  жизни,  питанию  и  определения  целесообразности
#
# проведения аллерген-специфической иммунотерапии [47,58-61].
#
# Уровень убедительности рекомендаций -С (уровень достоверности доказательств -  5)
#
# Комментарии:  Определение  уровня  аллерген-специфических  1§Е  антител  в
#
# сыворотке  (Исследование  уровня  антител  к  антигенам  растительного,  животного  и
#
# химического  происхождения  в  крови)  особенно  важно  при  неубедительных результатах
#
# кожных  проб либо  при  невозможности  их  постановки  (например,  в  период  обострения
#
# аллергического
#
# заболевания  ичи  наличии  иных  противопоказаний),  отсутствии
#
# необходимых
#
# диагностических
#
# аллергенов.  Отчет
#
# по  тесту
#
# выглядит
#
# как
#
# количественный результат и считается позитивным при значении > 0.70 Ш/1.
#
# При  динамическом  наблюдении  в  течение  года  возможно  повторное  проведение
#
# исследования при подозрении на появление новой клинически значимой сенсибилизации.
#
# Интерпретация  полученных  результатов  аллергообследования  проводится  в
#
# сопоставлении  с  данными  анамнеза  и  клинической  картиной,  так  как  сенсибилизация
#
# может быть клинически значимой ичи латентной.
#
# Наличие  сенсибилизации  к  аллергенам  у   ребенка  с  эпизодами  бронхиальной
#
# обструкции является надежным прогностическими признаком развития БА в дальнейшем
#
# [62].
#
# Сенсибилизация  к  аэроаллергенам  наблюдается  у   большинства  детей  с  БА  в
#
# возрасте  старше  3-х  лет.  Однако  нормальные  показатели  специфических  1$Е  к
#
# распространенным аэроаллергенам не исключают диагноза БА  [47].
#
# 33
#
# •  Рекомендуется  исследование  кислотно-основного  состояния  и  газов  крови
#
# (парциального  напряжения  кислорода  -   Ра02;  парциального  напряжения
#
# углекислого  газа
#
# -   РаС02;  рН  и  уровень  бикарбонатов
#
# (НСОЗ-)  в
#
# артериальной  крови  в  период  тяжелого  обострения  БА,  сопровождающегося
#
# развитием тяжелой дыхательной недостаточности для оценки рисков  исходов,
#
# объективного
#
# понимания
#
# целесообразности
#
# оксигенотерапии
#
# или
#
# искусственной вентиляции легких [24,63].
#
# Уровень убедительности рекомендаций -С (уровень достоверности доказательств -  4)
#
# Комментарии:  требуется  динамическое  исследование  данных  показателей  для
#
# контроля состояния и оценки эффективности проводимой терапии.
#
# •  Рекомендуется  исследование  уровня  иммуноглобулинов  А,  М,  С  в  крови
#
# пациентам
#
# с  БА,  часто
#
# страдающим  повторными
#
# бактериальными
#
# инфекциями  верхних  и  нижних  дыхательных  путей  (гнойные  риносинуситы,
#
# отиты,  бронхиты,  пневмонии)  для  выявления  нарушений  со  стороны
#
# гуморального звена иммунитета  [64-66].
#
# Уровень убедительности рекомендаций -С (уровень достоверности доказательств - 5)
#
# Комментарии:  Иммунодефициты  (как  первичные,  что  наиболее  характерно  для
#
# детской  популяции,  так  и  вторичные)  с  преимущественным  нарушением  синтеза
#
# антител  проявляются  рецидивирующими  инфекциями  органов  дыхания  с  повышенной
#
# чувствительностью  к  инкапсулированным  бактериям,  торпидностъю  к  стандартным
#
# схемам антибиотикотерапии,  в конечном  итоге приводящим к структурным изменениям
#
# легочной  ткани
#
# (бронхоэктазы,  пневмосклероз,  пневмофиброз).  Раннее  выявление
#
# нарушений  синтеза  антител  при  соответствующей  клинической  картине  и  других
#
# диагностических  критериях  может  свидетельствовать  о  наличии  первичного  или
#
# вторичного  иммунодефицита
#
# с  преимущественной  недостаточностью
#
# синтеза
#
# антител,  оценить  целесообразность  проведения заместительной  терапии  препаратами
#
# иммуноглобулина  человека нормального  с  целью  снижения рисков повторных  инфекций  и
#
# нежелательных исходов [64—66]. Кратность исследования определяется индивидуально.
#
# •  Рекомендуется  исследование  уровня  глюкозы  в  крови  пациентам  с  тяжелым
#
# обострением  БА,  особенно у  пациентов  с  сопутствующим  сахарным диабетом,
#
# перед  назначением  кортикостероидов  системного  действия  (группа  АТХ
#
# Н02АВ:  Глюкокортикоиды))  и  в  дальнейшем  в  ходе  лечения  для  оценки
#
# 34
#
# исходного  уровня  и  мониторинга  с  целью  снижения  риска  нежелательных
#
# явлений от проводимой терапии  [67, 68].
#
# Уровень убедительности рекомендаций -С (уровень достоверности доказательств - 5)
#
# Комментарии:  Кортикостероиды  системного  действия  (группа  А Т Х   Н02ЛВ:
#
# Глюкокортикоиды))  имеют  широкий перечень побочных реакций,  в том  числе повышение
#
# уровня  глюкозы.  Пациентам  с  сопутствующим  сахарным  диабетом  и  факторами риска
#
# его  развития  (нарушение  толерантности  к  углеводам)  очень  важно  контролировать
#
# уровень  глюкозы  крови  во  время  лечения  глюкокортикоидами  [67,68].  Возможно,  это
#
# потребует дополнительного назначения сахароснижающих препаратов (группа А ТХ  А 10:
#
# Препараты для лечения сахарного диабета)  или увеличения дозировок ранее назначенных.
#
# Кратность выполнения определяется индивидуально.
#
# •  Рекомендуется  рассмотреть  возможность  выполнения  дополнительных
#
# исследований  (по  показаниям,  с  учетом  жалоб  и  клинической  картины):
#
# исследование уровня свободного трийодтиронина (СТЗ в крови), исследование
#
# уровня
#
# свободного  тироксина
#
# (СТ4)  в  крови,  исследование  уровня
#
# тиреотропного гормона (ТТГ) в крови, исследование уровня общего кортизола
#
# в  крови,  исследование  уровня  свободного  кортизола  в  моче,  исследование
#
# уровня  С-реактивного  белка  в  сыворотке  крови,  антинейтрофильных
#
# цитоплазматических
#
# антител
#
# (Определение
#
# маркеров
#
# А1ЧСА-
#
# ассоциированных  васкулитов:  РКЗ  (с-А1ЧСА),  МПО  (р-А1ЧСА)),  определения
#
# концентрации  Д-димера  в  крови,  микробиологическое
#
# (культуральное)
#
# исследование  мокроты
#
# на
#
# аэробные
#
# и  факультативно-анаэробные
#
# микроорганизмы,
#
# микробиологическое
#
# (культуральное)
#
# исследование
#
# мокроты  на  дрожжевые  грибы,
#
# микробиологическое
#
# (культуральное)
#
# исследование  мокроты  на  мицелиальные  грибы  с  целью  проведения
#
# дифференциальной  диагностики  бронхиальной  астмы  с  другой  патологией,
#
# или  в  случае  неконтролируемого  течения  тяжелой  бронхиальной  астмы  (при
#
# сохранении
#
# высокого
#
# комплаенса)
#
# для
#
# выявления
#
# сопутствующих
#
# заболеваний,
#
# утяжеляющих
#
# течение
#
# основного
#
# [4,6,21,61,66,79,139,146,149,279,377-3 86].
#
# Уровень убедительности рекомендаций -С (уровень достоверности доказательств - 5)
#
# Комментарии:  Перечень  исследований  может  быть  дополнен  в  зависимости  от
#
# клинической ситуации.
#
# 35
#
# 2.4

# %%
import PyPDF2

# %%
from PyPDF2 import PdfReader

# %%
reader = PdfReader("/content/359_3.pdf")
page = reader.pages[1]
print(page.extract_text())
# Out:
# ОглавлениеОглавление
# 2
# Список сокращений ............................................................................................................................ 6
# Термины и определения ..................................................................................................................... 9
# 1. Краткая информация по заболеванию или состоянию (группе заболеваний или
# состояний) ...................................................................................................................................  11
# 1.1 Определение заболевания или состояния (группы заболеваний или состояний) 11
# 1.2 Этиология и патогенез заболевания или состояния (группы заболеваний или
# состояний) ....................................................................................................................................... 11
# 1.3 Эпидемиология заболевания или состояния (группы заболеваний или состояний). 13
# 1.4 Особенности кодирования заболевания или состояния (группы заболеваний или
# состояний) по Международной статистической классификации болезней и проблем,
# связанных со здоровьем ................................................................................................................ 14
# 1.5 Классификация заболевания или состояния (группы заболеваний или состояний).. 14
# 1.6 Клиническая картина заболевания или состояния (группы заболеваний или
# состояний) ....................................................................................................................................... 21
# 2. Диагностика заболевания или состояния (группы заболеваний или состояний),
# медицинские показания и противопоказания к применению методов диагностики 24
# 2.1 Жалобы и анамнез .................................................................................................................. 26
# 2.2 Физикальное обследование .................................................................................................. 27
# 2.3 Лабораторные диагностические исследования ................................................................ 29
# 2.4 Инструментальные диагностические исследования ........................................................ 36
# 2.5 Иные диагностические исследования ................................................................................. 43
# 2.5.1 Диагностика профессиональной БА ................................................................................ 44
# 2.5.2 Подтверждение диагноза БА у лиц, подлежащих призыву на военную службу ....46
# 2.5.3 Дифференциальная диагностика Б А ............................................................................... 47
# 3. Лечение, включая медикаментозную и немедикаментозную терапии, диетотерапию,
# обезболивание, медицинские показания и противопоказания к применению методов
# лечения ................................................................................................................................................ 48
# 3.1 Медикаментозная терапия ....................................................................................  48

# %%
page = reader.pages[0]
print(page.extract_text())
# Out:
# Утверждено:
# Арийская ассоциацияУтверждено:
# Российское
# Респират
# Г М  *
# 2024г
# с°ЦпЫ
# тРУда , С )/1Я ‘ /Утверждено:
# Союз педиатров России
# Протокол а ^ 2 ^ Т т2 0 2 4 г
# -О ч 'Л.С.Нш&бва^тар%ов4\г\
# /?/ ^
# Г
# Клинические рекомендации
# Бронхиальная астма
# Кодирование по Международной
# статистической классификации
# болезней и проблем, связанных
# со здоровьем: 145.0,145.1,145.8,145.9,146 2  57.2,2 57.3,257.4,
# 257.5,145
# Возрастная группа: дети/взрослые
# Г од утверждения: 2024
# Год окончания действия: 2027
# Разработчик клинической рекомендации:
# •  Российская ассоциация аллергологов и клинических иммунологов
# • Российское респираторное общество
# • Союз педиатров России
# • Ассоциация врачей и специалистов медицины труда
# Одобрено на заседании научно-практического совета
# Министерства здравоохранения Российской Федерации
# (протокол от 22.08.2024г. № 37)

# %%
import PyPDF2
pdf_file = open('/content/359_3.pdf', 'rb')
read_pdf = PyPDF2.PdfReader(pdf_file)
# number_of_pages = len(pdf_file.pages)
# page = pdf_file.pages()
content = read_pdf.
content = read_pdf.extractText()
print (content.encode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-b72fdd58be02> in <cell line: 6>()
#       4 # number_of_pages = len(pdf_file.pages)
#       5 # page = pdf_file.pages()
# ----> 6 content = read_pdf.extractText()
#       7 print (content.encode('utf-8'))
#
# AttributeError: 'PdfReader' object has no attribute 'extractText'

# %%
url
# Out:
# 'https://apicr.minzdrav.gov.ru/api.ashx?op=GetClinrecPdf&id=359_3'

# %%
# Подгрузка библиотек
import requests as req
import pandas as pd
from datetime import datetime

# Парсинг + Запрос API
link = 'https://apicr.minzdrav.gov.ru/api.ashx?op=GetJsonClinrecs&ssid=undefined'
response = req.get(link).json()

# Модификация и формирование таблицы
base = {'id': [],
        'status': [],
        'db_id':[],
        'code': [],
        'version': [],
        'ver': 1,
        'age': [],
        'name': [],
        'Mkb': [],
        'ass': [],
        'publish_date': [],
        'NPC_approved': [],
        'apply_status': [],
        'prev_cr_id': []}
df = pd.DataFrame(base)
for i in range(len(response)):
  text = response[i].get('publish_date')
  text_01 = int(text[6:-2])/1000 + 10800
  date = datetime.fromtimestamp(text_01).strftime('%d-%m-%Y')
  up = {'publish_date': date}
  response[i].update(up)
  df = pd.concat([df, pd.DataFrame.from_records(response[i])] ,ignore_index=True)
  up = {}

#Сохранение результата
klin_rec = df.copy()
klin_rec.to_csv('/content/sample_data/klin_rec.csv', header=True)

# Взрослые
# klin_rec_adults = klin_rec[((klin_rec['age'] == 1) | (klin_rec['age'] == 3))]
# klin_rec_adults.to_csv('/content/sample_data/klin_rec_adults.csv', header=True)
# klin_rec_adults.to_excel('/content/sample_data/klin_rec_adults.xlsx', header=True)

# Дети
# klin_rec_сhildren = klin_rec[((klin_rec['age'] == 2) | (klin_rec['age'] == 3))]
# klin_rec_сhildren.to_csv('/content/sample_data/klin_rec_сhildren.csv', header=True)
# klin_rec_сhildren.to_excel('/content/sample_data/klin_rec_сhildren.xlsx', header=True)

# %%
# klin_rec.to_csv('/content/sample_data/klin_rec.csv', header=True)

# %%
# klin_rec.head(5)

# %%
# klin_rec.head(50)

# %%
result = klin_rec[klin_rec['Mkb'].str.contains('J', na=False)]
# result

# %%
type(result)

# %%
pulm = result.copy()
pulm.to_csv('/content/sample_data/pulm.csv', header=True)
# pulm

# %%
pulm.to_excel('/content/sample_data/pulm.xlsx', header=True)

# %%
klin_rec.loc[klin_rec['Mkb'] == 'J20']
# Out:
#         id  status   db_id   code  version  ver  age  \
# 572  381_2     0.0  1267.0  381.0      2.0    2  2.0
# 735  724_1     0.0  1342.0  724.0      1.0    2  1.0
#
#                                                   name  Mkb  \
# 572                                            Бронхит  J20
# 735  Острые респираторные вирусные инфекции (ОРВИ) ...  J20
#
#                                                    ass publish_date  \
# 572  Союз педиатров России, Межрегиональная ассоциа...   27-09-2021
# 735  Некоммерческое партнерство «Национальное научн...   15-02-2022
#
#     NPC_approved apply_status prev_cr_id
# 572         True  Применяется       None
# 735         True  Применяется       None

# %%
klin_rec['apply_status'].unique()
# Out:
# array(['Применяется', 'Применение отложено. Применяется ',
#        'Применение отложено'], dtype=object)

# %%
type(klin_rec)
# Out:
# pandas.core.frame.DataFrame

# %%
# .loc[((df['col1'] == 'A') & (df['col2' ] == 'G'))]
klin_rec.loc[klin_rec['name'] == 'Бронхиальная астма']
# Out:
#         id  status   db_id   code  version  ver  age                name  Mkb  \
# 523  359_2     0.0  1143.0  359.0      2.0    2  3.0  Бронхиальная астма  J45
# 524  359_2     0.0  1143.0  359.0      2.0    2  3.0  Бронхиальная астма  J46
#
#                                                    ass publish_date  \
# 523  Российское респираторное общество, Российская ...   23-06-2021
# 524  Российское респираторное общество, Российская ...   23-06-2021
#
#     NPC_approved apply_status prev_cr_id
# 523         True  Применяется       None
# 524         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Аллергический ринит']
# Out:
#          id  status   db_id   code  version  ver  age                 name  \
# 1431  261_2     0.0  1479.0  261.0      2.0    2  3.0  Аллергический ринит
# 1432  261_2     0.0  1479.0  261.0      2.0    2  3.0  Аллергический ринит
# 1433  261_2     0.0  1479.0  261.0      2.0    2  3.0  Аллергический ринит
# 1434  261_2     0.0  1479.0  261.0      2.0    2  3.0  Аллергический ринит
#
#         Mkb                                                ass publish_date  \
# 1431  J30.1  Российская ассоциация аллергологов и клиническ...   11-07-2024
# 1432  J30.2  Российская ассоциация аллергологов и клиническ...   11-07-2024
# 1433  J30.3  Российская ассоциация аллергологов и клиническ...   11-07-2024
# 1434  J30.4  Российская ассоциация аллергологов и клиническ...   11-07-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1431         True  Применение отложено
# 1432         True  Применение отложено
# 1433         True  Применение отложено
# 1434         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Анафилактический шок']
# Out:
#         id  status  db_id   code  version  ver  age                  name  \
# 128  263_1     0.0  186.0  263.0      1.0    1  3.0  Анафилактический шок
# 129  263_1     0.0  186.0  263.0      1.0    1  3.0  Анафилактический шок
# 130  263_1     0.0  186.0  263.0      1.0    1  3.0  Анафилактический шок
# 131  263_1     0.0  186.0  263.0      1.0    1  3.0  Анафилактический шок
#
#        Mkb                                                ass publish_date  \
# 128  T78.0  Российская ассоциация аллергологов и клиническ...   02-02-2021
# 129  T78.2  Российская ассоциация аллергологов и клиническ...   02-02-2021
# 130  T80.5  Российская ассоциация аллергологов и клиническ...   02-02-2021
# 131  T88.6  Российская ассоциация аллергологов и клиническ...   02-02-2021
#
#     NPC_approved apply_status prev_cr_id
# 128         True  Применяется       None
# 129         True  Применяется       None
# 130         True  Применяется       None
# 131         True  Применяется       None

# %%
klin_rec['name'][611]
# Out:
# 'Атопический дерматит '

# %%
klin_rec.loc[klin_rec['name'] == 'Атопический дерматит ']
# Out:
#         id  status   db_id   code  version  ver  age                   name  \
# 611  265_2     0.0  1204.0  265.0      2.0    2  3.0  Атопический дерматит
#
#      Mkb                                                ass publish_date  \
# 611  L20  Общероссийская общественная организация "Росси...   26-08-2021
#
#     NPC_approved apply_status prev_cr_id
# 611         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Классическая фенилкетонурия и другие виды гиперфенилаланинемии']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1495  482_2     0.0  1488.0  482.0      2.0    2  3.0
# 1496  482_2     0.0  1488.0  482.0      2.0    2  3.0
# 1497  482_2     0.0  1488.0  482.0      2.0    2  3.0
#
#                                                    name    Mkb  \
# 1495  Классическая фенилкетонурия и другие виды гипе...  E70.0
# 1496  Классическая фенилкетонурия и другие виды гипе...  E70.1
# 1497  Классическая фенилкетонурия и другие виды гипе...  E70.9
#
#                                                     ass publish_date  \
# 1495  Ассоциация медицинских генетиков, Союз педиатр...   18-07-2024
# 1496  Ассоциация медицинских генетиков, Союз педиатр...   18-07-2024
# 1497  Ассоциация медицинских генетиков, Союз педиатр...   18-07-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1495         True  Применение отложено
# 1496         True  Применение отложено
# 1497         True  Применение отложено

# %%
klin_rec.loc[klin_rec['Mkb'] == 'E70.0']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1495  482_2     0.0  1488.0  482.0      2.0    2  3.0
#
#                                                    name    Mkb  \
# 1495  Классическая фенилкетонурия и другие виды гипе...  E70.0
#
#                                                     ass publish_date  \
# 1495  Ассоциация медицинских генетиков, Союз педиатр...   18-07-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1495         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь Фабри']
# Out:
#          id  status   db_id   code  version  ver  age           name    Mkb  \
# 1500  318_2     0.0  1491.0  318.0      2.0    2  3.0  Болезнь Фабри  E75.2
#
#                                                     ass publish_date  \
# 1500  Ассоциация медицинских генетиков, Союз педиатр...   19-07-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1500         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь Помпе']
# Out:
#         id  status  db_id   code  version  ver  age           name    Mkb  \
# 246  317_1     0.0  975.0  317.0      1.0    2  3.0  Болезнь Помпе  E74.0
#
#                                                    ass publish_date  \
# 246  Ассоциация медицинских генетиков, Союз педиатр...   18-02-2020
#
#     NPC_approved apply_status prev_cr_id
# 246         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Нарушения обмена галактозы (Галактоземия)']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1671  375_3     0.0  1536.0  375.0      3.0    2  3.0
#
#                                            name    Mkb  \
# 1671  Нарушения обмена галактозы (Галактоземия)  E74.2
#
#                                                     ass publish_date  \
# 1671  Ассоциация медицинских генетиков, Союз педиатр...   21-08-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1671         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Глутаровая ацидурия тип 1']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1670  406_3     0.0  1535.0  406.0      3.0    2  3.0
#
#                            name    Mkb  \
# 1670  Глутаровая ацидурия тип 1  E72.3
#
#                                                     ass publish_date  \
# 1670  Ассоциация медицинских генетиков, Союз педиатр...   20-08-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1670         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Изовалериановая ацидемия/ацидурия']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1673  405_3     0.0  1538.0  405.0      3.0    2  3.0
#
#                                    name    Mkb  \
# 1673  Изовалериановая ацидемия/ацидурия  E71.1
#
#                                                     ass publish_date  \
# 1673  Союз педиатров России, Ассоциация медицинских ...   21-08-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1673         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Другие виды нарушения обмена аминокислот с разветвленной цепью (Метилмалоновая ацидемия /ацидурия)']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1447  387_3     0.0  1483.0  387.0      3.0    2  3.0
#
#                                                    name    Mkb  \
# 1447  Другие виды нарушения обмена аминокислот с раз...  E71.1
#
#                                                     ass publish_date  \
# 1447  Союз педиатров России, Ассоциация медицинских ...   12-07-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1447         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Кистозный фиброз (муковисцидоз)']
# Out:
#         id  status   db_id   code  version  ver  age  \
# 688  372_2     0.0  1228.0  372.0      2.0    2  3.0
#
#                                 name  Mkb  \
# 688  Кистозный фиброз (муковисцидоз)  E84
#
#                                                    ass publish_date  \
# 688  Союз педиатров России, Ассоциация медицинских ...   03-09-2021
#
#     NPC_approved apply_status prev_cr_id
# 688         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Мукополисахаридоз тип VI']
# Out:
#         id  status  db_id   code  version  ver  age                      name  \
# 244  293_1     0.0  973.0  293.0      1.0    2  1.0  Мукополисахаридоз тип VI
#
#        Mkb                                                ass publish_date  \
# 244  E76.2  Ассоциация медицинских генетиков, Союз педиатр...   18-02-2020
#
#     NPC_approved apply_status prev_cr_id
# 244         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Мукополисахаридоз тип I']
# Out:
#         id  status   db_id   code  version  ver  age                     name  \
# 242  291_1     0.0   971.0  291.0      1.0    2  1.0  Мукополисахаридоз тип I
# 578  380_2     0.0  1176.0  380.0      2.0    2  2.0  Мукополисахаридоз тип I
#
#        Mkb                                                ass publish_date  \
# 242  E76.0  Ассоциация медицинских генетиков, Союз педиатр...   19-02-2020
# 578  E76.0  Союз педиатров России, Ассоциация медицинских ...   08-07-2021
#
#     NPC_approved apply_status prev_cr_id
# 242         True  Применяется       None
# 578         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Мукополисахаридоз тип II']
# Out:
#         id  status   db_id   code  version  ver  age  \
# 243  292_1     0.0   972.0  292.0      1.0    2  1.0
# 579  392_2     0.0  1177.0  392.0      2.0    2  2.0
#
#                          name    Mkb  \
# 243  Мукополисахаридоз тип II  E76.1
# 579  Мукополисахаридоз тип II  E76.1
#
#                                                    ass publish_date  \
# 243  Ассоциация медицинских генетиков, Союз педиатр...   18-02-2020
# 579  Союз педиатров России, Ассоциация медицинских ...   08-07-2021
#
#     NPC_approved apply_status prev_cr_id
# 243         True  Применяется       None
# 579         True  Применяется       None

# %%
klin_rec.loc[klin_rec['Mkb'] == 'E71.3']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1674  694_2     0.0  1539.0  694.0      2.0    2  3.0
#
#                                                    name    Mkb  \
# 1674  Нарушения митохондриального β-окисления жирных...  E71.3
#
#                                                     ass publish_date  \
# 1674  Ассоциация медицинских генетиков, Союз педиатр...   21-08-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1674         True  Применение отложено

# %%
klin_rec['name'][1674]
# Out:
# 'Нарушения митохондриального β-окисления жирных кислот  '

# %%
klin_rec.loc[klin_rec['name'] == 'Нарушения митохондриального β-окисления жирных кислот  ']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1674  694_2     0.0  1539.0  694.0      2.0    2  3.0
#
#                                                    name    Mkb  \
# 1674  Нарушения митохондриального β-окисления жирных...  E71.3
#
#                                                     ass publish_date  \
# 1674  Ассоциация медицинских генетиков, Союз педиатр...   21-08-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1674         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Наследственная тирозинемия 1 типа']
# Out:
#          id  status   db_id   code  version  ver  age  \
# 1675  409_3     0.0  1540.0  409.0      3.0    2  3.0
#
#                                    name    Mkb  \
# 1675  Наследственная тирозинемия 1 типа  E70.2
#
#                                                     ass publish_date  \
# 1675  Союз педиатров России, Ассоциация медицинских ...   21-08-2024
#
#      NPC_approved         apply_status prev_cr_id
# 1675         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь Ниманна-Пика тип С']
# Out:
#         id  status  db_id   code  version  ver  age  \
# 245  294_1     0.0  974.0  294.0      1.0    2  3.0
#
#                            name    Mkb  \
# 245  Болезнь Ниманна-Пика тип С  E75.2
#
#                                                    ass publish_date  \
# 245  Ассоциация медицинских генетиков, Союз педиатр...   18-02-2020
#
#     NPC_approved apply_status prev_cr_id
# 245         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Острые порфирии']
# Out:
#         id  status   db_id   code  version  ver  age             name    Mkb  \
# 781  145_2     0.0  1260.0  145.0      2.0    2  3.0  Острые порфирии  E80.2
#
#                                                    ass publish_date  \
# 781  Национальное гематологическое общество, РОО «О...   22-09-2021
#
#     NPC_approved apply_status prev_cr_id
# 781         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Другие виды нарушения обмена аминокислот с разветвленной цепью (Пропионовая ацидемия /ацидурия)']
# Out:
#         id  status   db_id   code  version  ver  age  \
# 784  681_1     0.0  1264.0  681.0      1.0    2  3.0
#
#                                                   name    Mkb  \
# 784  Другие виды нарушения обмена аминокислот с раз...  E71.1
#
#                                                    ass publish_date  \
# 784  Союз педиатров России, Ассоциация медицинских ...   23-09-2021
#
#     NPC_approved apply_status prev_cr_id
# 784         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь Крона']
# Out:
#          id  status   db_id   code  version  ver  age           name  Mkb  \
# 785   682_1     0.0  1265.0  682.0      1.0    2  2.0  Болезнь Крона  K50
# 1464  176_2     0.0  1485.0  176.0      2.0    2  1.0  Болезнь Крона  K50
#
#                                                     ass publish_date  \
# 785   Союз педиатров России, Общероссийская обществе...   27-09-2021
# 1464  Общероссийская общественная организация "Ассоц...   16-07-2024
#
#      NPC_approved         apply_status prev_cr_id
# 785          True          Применяется       None
# 1464         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Желчнокаменная болезнь']
# Out:
#         id  status   db_id   code  version  ver  age                    name  \
# 612  580_2     0.0  1211.0  580.0      2.0    2  2.0  Желчнокаменная болезнь
#
#      Mkb                                                ass publish_date  \
# 612  K80  Союз педиатров России, Общероссийская обществе...   31-08-2021
#
#     NPC_approved apply_status prev_cr_id
# 612         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Язвенная болезнь желудка и/или двенадцатиперстной кишки']
# Out:
#         id  status   db_id   code  version  ver  age  \
# 786  388_2     0.0  1266.0  388.0      2.0    2  2.0
# 787  388_2     0.0  1266.0  388.0      2.0    2  2.0
#
#                                                   name  Mkb  \
# 786  Язвенная болезнь желудка и/или двенадцатиперст...  K25
# 787  Язвенная болезнь желудка и/или двенадцатиперст...  K26
#
#                                                    ass publish_date  \
# 786  Союз педиатров России, Межрегиональная ассоциа...   27-09-2021
# 787  Союз педиатров России, Межрегиональная ассоциа...   27-09-2021
#
#     NPC_approved apply_status prev_cr_id
# 786         True  Применяется       None
# 787         True  Применяется       None

# %%
klin_rec.loc[klin_rec['name'] == 'Язвенный колит']
# Out:
#          id  status   db_id   code  version  ver  age            name  Mkb  \
# 857   391_2     0.0  1296.0  391.0      2.0    2  2.0  Язвенный колит  K51
# 1401  193_2     0.0  1466.0  193.0      2.0    2  1.0  Язвенный колит  K51
#
#                                                     ass publish_date  \
# 857   Союз педиатров России, Общероссийская обществе...   09-11-2021
# 1401  Общероссийская общественная организация "Ассоц...   29-05-2024
#
#      NPC_approved         apply_status prev_cr_id
# 857          True          Применяется       None
# 1401         True  Применение отложено

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь «кленового сиропа»']

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь «кленового сиропа»']

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь «кленового сиропа»']

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь «кленового сиропа»']

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь «кленового сиропа»']

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь «кленового сиропа»']

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь «кленового сиропа»']

# %%
klin_rec.loc[klin_rec['name'] == 'Болезнь «кленового сиропа»']
